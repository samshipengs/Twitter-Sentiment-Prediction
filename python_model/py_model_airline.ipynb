# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import time
from scipy.stats import itemfreq
import random

import theano
import theano.tensor as T
import lasagne
from sklearn.model_selection import StratifiedKFold

# import user defined load_data to build input data
from load_data import Data

# Enter your own file path here, in the path it should contain two 
# directories, data and word2vec
# FILE_PATH = '/home/sam/Hhd/twitter_sentiment/'
FILE_PATH = '/home/sam/Data/twitter_sentiment/'
# Out:
# Using cuDNN version 5110 on context None
# Mapped name None to device cuda: GeForce GTX 965M (0000:01:00.0)

# %% [markdown]
# ### Use Airline data

# %%
airline_data = Data('Airline-Sentiment-2-w-AA.csv', FILE_PATH)
airline_df = airline_data.csv_df(['airline_sentiment', 'text']) # load data
airline_data.pre_process(airline_df) # pre-process data
# drop neutral
# airline_df = airline_data.drop_value(airline_df, 'airline_sentiment', 'neutral')
airline_df.head()
# Out:
# Loading csv: Airline-Sentiment-2-w-AA.csv ...
# Note: pre_process changes the dataframe inplace.
#   airline_sentiment                                               text  \
# 0           neutral                                         What  said
# 1          positive   plus youve added commercials to the experienc...
# 2           neutral   I didnt today Must mean I need to take anothe...
# 3          negative   its really aggressive to blast obnoxious ente...
# 4          negative            and its a really big bad thing about it
#
#                                            tokenized
# 0                                             [said]
# 1  [plus, youve, added, commercials, experience, ...
# 2  [didnt, today, must, mean, need, take, another...
# 3  [really, aggressive, blast, obnoxious, enterta...
# 4                          [really, big, bad, thing]

# %%
# convert categorical value to int class
class_label = {'positive': 1, 'neutral': 2, 'negative': 3}
# class_label = {'positive': 1, 'negative': 2}
# airline_df['class'] = airline_df['airline_sentiment'].apply(lambda x: class_label[x])
# airline_df.drop('airline_sentiment', inplace=True, axis=1)
airline_df = airline_data.cat2num(airline_df,'airline_sentiment', 'class', class_label)
airline_df.head()
# Out:
# class
# Done converting categorical to numeric, this changes df.
#                                                 text  \
# 0                                         What  said
# 1   plus youve added commercials to the experienc...
# 2   I didnt today Must mean I need to take anothe...
# 3   its really aggressive to blast obnoxious ente...
# 4            and its a really big bad thing about it
#
#                                            tokenized  class
# 0                                             [said]      2
# 1  [plus, youve, added, commercials, experience, ...      1
# 2  [didnt, today, must, mean, need, take, another...      2
# 3  [really, aggressive, blast, obnoxious, enterta...      3
# 4                          [really, big, bad, thing]      3

# %%
# lets take a look of the 
airline_df['class'].value_counts()
# Out:
# 3    9178
# 2    3099
# 1    2363
# Name: class, dtype: int64

# %%
# comment out if do not want class balance
airline_df = airline_data.balance_class(airline_df)
# and check again
airline_df['class'].value_counts()
# Out:
# 3    3099
# 2    3099
# 1    2363
# Name: class, dtype: int64

# %%
airline_df.head()
# Out:
#                                                 text  \
# 0                                         What  said
# 1   plus youve added commercials to the experienc...
# 2   I didnt today Must mean I need to take anothe...
# 3   seriously would pay  a flight for seats that ...
# 4   yes nearly every time I fly VX this ear worm ...
#
#                                            tokenized  class
# 0                                             [said]      2
# 1  [plus, youve, added, commercials, experience, ...      1
# 2  [didnt, today, must, mean, need, take, another...      2
# 3  [seriously, would, pay, flight, seats, didnt, ...      3
# 4  [yes, nearly, every, time, fly, vx, ear, worm,...      1

# %%
# train or load the model
model = airline_data.build_wordvec(size=500)
# Out:
# 2017-03-18 16:39:05,538 : INFO : collecting all words and their counts
# 2017-03-18 16:39:05,547 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# Training for tweets500.model.bin ...
# 2017-03-18 16:39:11,108 : INFO : collected 253854 word types from a corpus of 17005207 raw words and 1701 sentences
# 2017-03-18 16:39:11,109 : INFO : Loading a fresh vocabulary
# 2017-03-18 16:39:11,448 : INFO : min_count=5 retains 71290 unique words (28% of original 253854, drops 182564)
# 2017-03-18 16:39:11,448 : INFO : min_count=5 leaves 16718844 word corpus (98% of original 17005207, drops 286363)
# 2017-03-18 16:39:11,586 : INFO : deleting the raw counts dictionary of 253854 items
# 2017-03-18 16:39:11,612 : INFO : sample=0.001 downsamples 38 most-common words
# 2017-03-18 16:39:11,613 : INFO : downsampling leaves estimated 12506280 word corpus (74.8% of prior 16718844)
# 2017-03-18 16:39:11,614 : INFO : estimated required memory for 71290 words and 500 dimensions: 320805000 bytes
# 2017-03-18 16:39:11,860 : INFO : resetting layer weights
# 2017-03-18 16:39:12,885 : INFO : training model with 4 workers on 71290 vocabulary and 500 features, using sg=1 hs=0 sample=0.001 negative=5 window=5
# 2017-03-18 16:39:12,886 : INFO : expecting 1701 sentences, matching count from corpus used for vocabulary survey
# 2017-03-18 16:39:13,893 : INFO : PROGRESS: at 0.29% examples, 184291 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:14,901 : INFO : PROGRESS: at 0.63% examples, 198262 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:15,903 : INFO : PROGRESS: at 0.95% examples, 197393 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:16,905 : INFO : PROGRESS: at 1.25% examples, 192678 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:17,911 : INFO : PROGRESS: at 1.59% examples, 196145 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:19,006 : INFO : PROGRESS: at 1.93% examples, 195584 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:20,044 : INFO : PROGRESS: at 2.22% examples, 192489 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:21,046 : INFO : PROGRESS: at 2.54% examples, 193258 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:22,102 : INFO : PROGRESS: at 2.88% examples, 194242 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:39:23,130 : INFO : PROGRESS: at 3.21% examples, 194848 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:24,153 : INFO : PROGRESS: at 3.55% examples, 196134 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:39:25,161 : INFO : PROGRESS: at 3.89% examples, 197357 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:39:26,164 : INFO : PROGRESS: at 4.23% examples, 198496 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:39:27,179 : INFO : PROGRESS: at 4.54% examples, 197833 words/s, in_qsize 8, out_qsize 1
# 2017-03-18 16:39:28,185 : INFO : PROGRESS: at 4.88% examples, 198957 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:39:29,194 : INFO : PROGRESS: at 5.23% examples, 200276 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:30,204 : INFO : PROGRESS: at 5.55% examples, 200185 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:39:31,217 : INFO : PROGRESS: at 5.89% examples, 200889 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:39:32,235 : INFO : PROGRESS: at 6.18% examples, 199957 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:39:33,236 : INFO : PROGRESS: at 6.49% examples, 199626 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:34,290 : INFO : PROGRESS: at 6.83% examples, 199905 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:35,309 : INFO : PROGRESS: at 7.16% examples, 200170 words/s, in_qsize 7, out_qsize 1
# 2017-03-18 16:39:36,309 : INFO : PROGRESS: at 7.50% examples, 200669 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:37,316 : INFO : PROGRESS: at 7.84% examples, 201140 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:39:38,338 : INFO : PROGRESS: at 8.17% examples, 201156 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:39,339 : INFO : PROGRESS: at 8.50% examples, 201389 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:40,354 : INFO : PROGRESS: at 8.84% examples, 201700 words/s, in_qsize 8, out_qsize 1
# 2017-03-18 16:39:41,356 : INFO : PROGRESS: at 9.17% examples, 201894 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:39:42,378 : INFO : PROGRESS: at 9.50% examples, 201905 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:43,388 : INFO : PROGRESS: at 9.83% examples, 202013 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:44,401 : INFO : PROGRESS: at 10.16% examples, 202104 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:45,439 : INFO : PROGRESS: at 10.50% examples, 202165 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:46,465 : INFO : PROGRESS: at 10.84% examples, 202435 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:47,475 : INFO : PROGRESS: at 11.17% examples, 202514 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:39:48,478 : INFO : PROGRESS: at 11.52% examples, 202978 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:39:49,537 : INFO : PROGRESS: at 11.86% examples, 202989 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:50,573 : INFO : PROGRESS: at 12.20% examples, 203090 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:39:51,586 : INFO : PROGRESS: at 12.56% examples, 203444 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:52,638 : INFO : PROGRESS: at 12.90% examples, 203434 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:39:53,679 : INFO : PROGRESS: at 13.24% examples, 203471 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:39:54,680 : INFO : PROGRESS: at 13.57% examples, 203534 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:55,690 : INFO : PROGRESS: at 13.90% examples, 203569 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:39:56,718 : INFO : PROGRESS: at 14.23% examples, 203536 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:57,723 : INFO : PROGRESS: at 14.54% examples, 203418 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:58,735 : INFO : PROGRESS: at 14.89% examples, 203607 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:39:59,738 : INFO : PROGRESS: at 15.24% examples, 203710 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:40:00,760 : INFO : PROGRESS: at 15.59% examples, 203835 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:01,784 : INFO : PROGRESS: at 15.93% examples, 203914 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:02,813 : INFO : PROGRESS: at 16.27% examples, 203957 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:03,842 : INFO : PROGRESS: at 16.61% examples, 203997 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:04,855 : INFO : PROGRESS: at 16.97% examples, 204280 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:05,914 : INFO : PROGRESS: at 17.31% examples, 204227 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:06,944 : INFO : PROGRESS: at 17.66% examples, 204408 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:40:08,055 : INFO : PROGRESS: at 17.99% examples, 204110 words/s, in_qsize 8, out_qsize 1
# 2017-03-18 16:40:09,062 : INFO : PROGRESS: at 18.35% examples, 204411 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:40:10,132 : INFO : PROGRESS: at 18.69% examples, 204279 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:40:11,143 : INFO : PROGRESS: at 19.05% examples, 204511 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:40:12,154 : INFO : PROGRESS: at 19.37% examples, 204366 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:40:13,158 : INFO : PROGRESS: at 19.71% examples, 204446 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:40:14,193 : INFO : PROGRESS: at 20.06% examples, 204593 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:40:15,215 : INFO : PROGRESS: at 20.39% examples, 204556 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:16,234 : INFO : PROGRESS: at 20.72% examples, 204507 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:40:17,286 : INFO : PROGRESS: at 21.07% examples, 204578 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:18,280 : INFO : PROGRESS: at 21.40% examples, 204493 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:19,375 : INFO : PROGRESS: at 21.74% examples, 204315 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:40:20,382 : INFO : PROGRESS: at 22.09% examples, 204509 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:21,436 : INFO : PROGRESS: at 22.45% examples, 204573 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:22,480 : INFO : PROGRESS: at 22.79% examples, 204572 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:23,527 : INFO : PROGRESS: at 23.13% examples, 204558 words/s, in_qsize 8, out_qsize 1
# 2017-03-18 16:40:24,552 : INFO : PROGRESS: at 23.47% examples, 204590 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:40:25,563 : INFO : PROGRESS: at 23.81% examples, 204669 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:26,569 : INFO : PROGRESS: at 24.15% examples, 204770 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:40:27,570 : INFO : PROGRESS: at 24.48% examples, 204788 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:28,574 : INFO : PROGRESS: at 24.79% examples, 204660 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:40:29,579 : INFO : PROGRESS: at 25.13% examples, 204756 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:40:30,597 : INFO : PROGRESS: at 25.47% examples, 204847 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:31,621 : INFO : PROGRESS: at 25.77% examples, 204641 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:32,624 : INFO : PROGRESS: at 26.10% examples, 204691 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:33,646 : INFO : PROGRESS: at 26.44% examples, 204773 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:34,669 : INFO : PROGRESS: at 26.78% examples, 204853 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:35,678 : INFO : PROGRESS: at 27.13% examples, 204961 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:40:36,692 : INFO : PROGRESS: at 27.45% examples, 204964 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:37,717 : INFO : PROGRESS: at 27.78% examples, 204899 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:40:38,759 : INFO : PROGRESS: at 28.12% examples, 204896 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:40:39,775 : INFO : PROGRESS: at 28.47% examples, 204986 words/s, in_qsize 7, out_qsize 1
# 2017-03-18 16:40:40,783 : INFO : PROGRESS: at 28.81% examples, 205045 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:41,800 : INFO : PROGRESS: at 29.11% examples, 204871 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:42,827 : INFO : PROGRESS: at 29.45% examples, 204915 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:43,844 : INFO : PROGRESS: at 29.79% examples, 204975 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:44,853 : INFO : PROGRESS: at 30.14% examples, 205060 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:40:45,933 : INFO : PROGRESS: at 30.48% examples, 204975 words/s, in_qsize 8, out_qsize 1
# 2017-03-18 16:40:46,956 : INFO : PROGRESS: at 30.82% examples, 205028 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:48,026 : INFO : PROGRESS: at 31.16% examples, 204975 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:40:49,042 : INFO : PROGRESS: at 31.50% examples, 205020 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:50,075 : INFO : PROGRESS: at 31.84% examples, 205041 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:51,108 : INFO : PROGRESS: at 32.18% examples, 205078 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:52,126 : INFO : PROGRESS: at 32.49% examples, 204893 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:53,203 : INFO : PROGRESS: at 32.84% examples, 204919 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:54,212 : INFO : PROGRESS: at 33.18% examples, 204961 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:55,238 : INFO : PROGRESS: at 33.52% examples, 204994 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:56,247 : INFO : PROGRESS: at 33.84% examples, 204930 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:40:57,257 : INFO : PROGRESS: at 34.18% examples, 205002 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:40:58,346 : INFO : PROGRESS: at 34.53% examples, 204978 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:40:59,355 : INFO : PROGRESS: at 34.85% examples, 204916 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:00,360 : INFO : PROGRESS: at 35.18% examples, 204814 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:01,366 : INFO : PROGRESS: at 35.52% examples, 204824 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:02,448 : INFO : PROGRESS: at 35.83% examples, 204532 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:41:03,559 : INFO : PROGRESS: at 36.16% examples, 204333 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:04,582 : INFO : PROGRESS: at 36.48% examples, 204307 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:05,655 : INFO : PROGRESS: at 36.77% examples, 203925 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:41:06,756 : INFO : PROGRESS: at 37.12% examples, 203897 words/s, in_qsize 7, out_qsize 1
# 2017-03-18 16:41:07,821 : INFO : PROGRESS: at 37.45% examples, 203781 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:08,859 : INFO : PROGRESS: at 37.80% examples, 203870 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:09,867 : INFO : PROGRESS: at 38.14% examples, 203945 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:10,890 : INFO : PROGRESS: at 38.45% examples, 203768 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:11,928 : INFO : PROGRESS: at 38.77% examples, 203640 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:12,964 : INFO : PROGRESS: at 39.08% examples, 203557 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:14,034 : INFO : PROGRESS: at 39.42% examples, 203487 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:15,048 : INFO : PROGRESS: at 39.76% examples, 203531 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:41:16,065 : INFO : PROGRESS: at 40.11% examples, 203584 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:17,097 : INFO : PROGRESS: at 40.46% examples, 203677 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:18,140 : INFO : PROGRESS: at 40.80% examples, 203676 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:19,184 : INFO : PROGRESS: at 41.15% examples, 203710 words/s, in_qsize 7, out_qsize 1
# 2017-03-18 16:41:20,220 : INFO : PROGRESS: at 41.50% examples, 203755 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:41:21,245 : INFO : PROGRESS: at 41.85% examples, 203783 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:22,246 : INFO : PROGRESS: at 42.18% examples, 203769 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:23,257 : INFO : PROGRESS: at 42.52% examples, 203822 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:24,258 : INFO : PROGRESS: at 42.87% examples, 203949 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:25,273 : INFO : PROGRESS: at 43.20% examples, 203933 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:41:26,332 : INFO : PROGRESS: at 43.54% examples, 203920 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:41:27,374 : INFO : PROGRESS: at 43.89% examples, 203977 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:28,412 : INFO : PROGRESS: at 44.23% examples, 203995 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:29,421 : INFO : PROGRESS: at 44.56% examples, 203999 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:30,464 : INFO : PROGRESS: at 44.90% examples, 204023 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:31,474 : INFO : PROGRESS: at 45.24% examples, 204088 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:41:32,529 : INFO : PROGRESS: at 45.56% examples, 203989 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:41:33,589 : INFO : PROGRESS: at 45.89% examples, 203931 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:34,626 : INFO : PROGRESS: at 46.23% examples, 203969 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:35,649 : INFO : PROGRESS: at 46.54% examples, 203866 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:41:36,680 : INFO : PROGRESS: at 46.81% examples, 203591 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:41:37,697 : INFO : PROGRESS: at 47.07% examples, 203292 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:38,733 : INFO : PROGRESS: at 47.37% examples, 203171 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:41:39,800 : INFO : PROGRESS: at 47.68% examples, 202990 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:40,825 : INFO : PROGRESS: at 48.01% examples, 202979 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:41,837 : INFO : PROGRESS: at 48.31% examples, 202885 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:42,860 : INFO : PROGRESS: at 48.63% examples, 202841 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:43,888 : INFO : PROGRESS: at 48.97% examples, 202875 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:41:44,933 : INFO : PROGRESS: at 49.28% examples, 202741 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:45,950 : INFO : PROGRESS: at 49.56% examples, 202551 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:47,001 : INFO : PROGRESS: at 49.85% examples, 202379 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:48,031 : INFO : PROGRESS: at 50.17% examples, 202316 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:49,049 : INFO : PROGRESS: at 50.48% examples, 202217 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:50,087 : INFO : PROGRESS: at 50.72% examples, 201869 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:41:51,165 : INFO : PROGRESS: at 51.01% examples, 201618 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:41:52,168 : INFO : PROGRESS: at 51.30% examples, 201512 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:41:53,173 : INFO : PROGRESS: at 51.63% examples, 201528 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:54,198 : INFO : PROGRESS: at 51.97% examples, 201578 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:41:55,203 : INFO : PROGRESS: at 52.31% examples, 201650 words/s, in_qsize 6, out_qsize 0
# 2017-03-18 16:41:56,206 : INFO : PROGRESS: at 52.64% examples, 201672 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:41:57,259 : INFO : PROGRESS: at 52.98% examples, 201676 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:41:58,372 : INFO : PROGRESS: at 53.27% examples, 201432 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:41:59,423 : INFO : PROGRESS: at 53.59% examples, 201358 words/s, in_qsize 7, out_qsize 1
# 2017-03-18 16:42:00,436 : INFO : PROGRESS: at 53.92% examples, 201371 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:01,514 : INFO : PROGRESS: at 54.25% examples, 201321 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:42:02,514 : INFO : PROGRESS: at 54.56% examples, 201262 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:03,540 : INFO : PROGRESS: at 54.81% examples, 201009 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:04,581 : INFO : PROGRESS: at 55.13% examples, 200889 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:42:05,588 : INFO : PROGRESS: at 55.41% examples, 200708 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:06,667 : INFO : PROGRESS: at 55.70% examples, 200463 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:07,729 : INFO : PROGRESS: at 56.03% examples, 200417 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:42:08,755 : INFO : PROGRESS: at 56.37% examples, 200456 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:42:09,780 : INFO : PROGRESS: at 56.72% examples, 200542 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:10,826 : INFO : PROGRESS: at 57.06% examples, 200558 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:11,853 : INFO : PROGRESS: at 57.38% examples, 200512 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:12,889 : INFO : PROGRESS: at 57.71% examples, 200509 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:42:13,914 : INFO : PROGRESS: at 58.04% examples, 200533 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:14,938 : INFO : PROGRESS: at 58.39% examples, 200583 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:15,947 : INFO : PROGRESS: at 58.72% examples, 200592 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:16,968 : INFO : PROGRESS: at 59.01% examples, 200484 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:17,970 : INFO : PROGRESS: at 59.35% examples, 200542 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:18,975 : INFO : PROGRESS: at 59.69% examples, 200585 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:42:20,064 : INFO : PROGRESS: at 60.01% examples, 200484 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:21,083 : INFO : PROGRESS: at 60.35% examples, 200537 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:22,111 : INFO : PROGRESS: at 60.69% examples, 200567 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:23,169 : INFO : PROGRESS: at 61.01% examples, 200485 words/s, in_qsize 7, out_qsize 1
# 2017-03-18 16:42:24,180 : INFO : PROGRESS: at 61.34% examples, 200475 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:25,198 : INFO : PROGRESS: at 61.61% examples, 200287 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:42:26,219 : INFO : PROGRESS: at 61.94% examples, 200283 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:42:27,221 : INFO : PROGRESS: at 62.28% examples, 200335 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:28,231 : INFO : PROGRESS: at 62.63% examples, 200436 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:42:29,246 : INFO : PROGRESS: at 62.95% examples, 200404 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:42:30,271 : INFO : PROGRESS: at 63.30% examples, 200481 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:42:31,321 : INFO : PROGRESS: at 63.64% examples, 200500 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:32,349 : INFO : PROGRESS: at 63.99% examples, 200529 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:42:33,354 : INFO : PROGRESS: at 64.33% examples, 200595 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:42:34,363 : INFO : PROGRESS: at 64.67% examples, 200661 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:35,383 : INFO : PROGRESS: at 65.01% examples, 200705 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:36,393 : INFO : PROGRESS: at 65.34% examples, 200735 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:37,418 : INFO : PROGRESS: at 65.66% examples, 200712 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:38,420 : INFO : PROGRESS: at 65.97% examples, 200718 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:39,432 : INFO : PROGRESS: at 66.31% examples, 200777 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:40,438 : INFO : PROGRESS: at 66.64% examples, 200806 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:41,440 : INFO : PROGRESS: at 66.96% examples, 200807 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:42:42,454 : INFO : PROGRESS: at 67.30% examples, 200862 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:43,486 : INFO : PROGRESS: at 67.65% examples, 200920 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:44,490 : INFO : PROGRESS: at 67.98% examples, 200946 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:45,533 : INFO : PROGRESS: at 68.32% examples, 200971 words/s, in_qsize 7, out_qsize 1
# 2017-03-18 16:42:46,528 : INFO : PROGRESS: at 68.65% examples, 201001 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:42:47,550 : INFO : PROGRESS: at 69.01% examples, 201072 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:48,567 : INFO : PROGRESS: at 69.34% examples, 201087 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:42:49,588 : INFO : PROGRESS: at 69.68% examples, 201126 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:50,601 : INFO : PROGRESS: at 70.02% examples, 201176 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:42:51,619 : INFO : PROGRESS: at 70.36% examples, 201213 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:52,637 : INFO : PROGRESS: at 70.70% examples, 201260 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:53,679 : INFO : PROGRESS: at 71.04% examples, 201284 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:54,724 : INFO : PROGRESS: at 71.39% examples, 201331 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:42:55,734 : INFO : PROGRESS: at 71.72% examples, 201343 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:56,746 : INFO : PROGRESS: at 72.02% examples, 201260 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:57,824 : INFO : PROGRESS: at 72.37% examples, 201278 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:42:58,843 : INFO : PROGRESS: at 72.66% examples, 201188 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:42:59,878 : INFO : PROGRESS: at 72.99% examples, 201172 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:00,900 : INFO : PROGRESS: at 73.32% examples, 201181 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:01,907 : INFO : PROGRESS: at 73.65% examples, 201198 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:02,930 : INFO : PROGRESS: at 73.99% examples, 201230 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:03,955 : INFO : PROGRESS: at 74.33% examples, 201265 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:04,982 : INFO : PROGRESS: at 74.66% examples, 201272 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:06,025 : INFO : PROGRESS: at 74.98% examples, 201218 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:07,064 : INFO : PROGRESS: at 75.33% examples, 201217 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:08,079 : INFO : PROGRESS: at 75.65% examples, 201177 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:09,121 : INFO : PROGRESS: at 75.98% examples, 201155 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:10,147 : INFO : PROGRESS: at 76.32% examples, 201180 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:11,212 : INFO : PROGRESS: at 76.67% examples, 201206 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:12,235 : INFO : PROGRESS: at 76.99% examples, 201179 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:13,252 : INFO : PROGRESS: at 77.32% examples, 201185 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:14,258 : INFO : PROGRESS: at 77.66% examples, 201223 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:15,281 : INFO : PROGRESS: at 77.99% examples, 201234 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:16,308 : INFO : PROGRESS: at 78.33% examples, 201249 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:17,404 : INFO : PROGRESS: at 78.67% examples, 201212 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:18,415 : INFO : PROGRESS: at 79.01% examples, 201246 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:19,434 : INFO : PROGRESS: at 79.35% examples, 201286 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:20,430 : INFO : PROGRESS: at 79.69% examples, 201317 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:21,439 : INFO : PROGRESS: at 80.02% examples, 201331 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:22,463 : INFO : PROGRESS: at 80.33% examples, 201271 words/s, in_qsize 8, out_qsize 1
# 2017-03-18 16:43:23,523 : INFO : PROGRESS: at 80.67% examples, 201270 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:24,536 : INFO : PROGRESS: at 81.00% examples, 201271 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:25,592 : INFO : PROGRESS: at 81.36% examples, 201304 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:26,602 : INFO : PROGRESS: at 81.69% examples, 201311 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:27,616 : INFO : PROGRESS: at 82.03% examples, 201346 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:28,613 : INFO : PROGRESS: at 82.36% examples, 201355 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:29,618 : INFO : PROGRESS: at 82.69% examples, 201371 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:30,649 : INFO : PROGRESS: at 83.03% examples, 201387 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:31,675 : INFO : PROGRESS: at 83.37% examples, 201414 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:32,683 : INFO : PROGRESS: at 83.72% examples, 201457 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:33,694 : INFO : PROGRESS: at 84.04% examples, 201468 words/s, in_qsize 8, out_qsize 1
# 2017-03-18 16:43:34,704 : INFO : PROGRESS: at 84.39% examples, 201503 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:35,716 : INFO : PROGRESS: at 84.70% examples, 201495 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:36,753 : INFO : PROGRESS: at 85.03% examples, 201486 words/s, in_qsize 8, out_qsize 1
# 2017-03-18 16:43:37,777 : INFO : PROGRESS: at 85.36% examples, 201492 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:38,817 : INFO : PROGRESS: at 85.67% examples, 201432 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:39,835 : INFO : PROGRESS: at 86.00% examples, 201448 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:40,843 : INFO : PROGRESS: at 86.30% examples, 201410 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:41,850 : INFO : PROGRESS: at 86.64% examples, 201463 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:42,846 : INFO : PROGRESS: at 86.96% examples, 201462 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:43,865 : INFO : PROGRESS: at 87.29% examples, 201472 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:44,897 : INFO : PROGRESS: at 87.62% examples, 201467 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:45,917 : INFO : PROGRESS: at 87.96% examples, 201494 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:46,956 : INFO : PROGRESS: at 88.31% examples, 201534 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:47,991 : INFO : PROGRESS: at 88.63% examples, 201505 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:49,008 : INFO : PROGRESS: at 88.94% examples, 201456 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:50,013 : INFO : PROGRESS: at 89.27% examples, 201471 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:51,037 : INFO : PROGRESS: at 89.59% examples, 201475 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:52,051 : INFO : PROGRESS: at 89.89% examples, 201406 words/s, in_qsize 8, out_qsize 1
# 2017-03-18 16:43:53,102 : INFO : PROGRESS: at 90.22% examples, 201386 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:54,118 : INFO : PROGRESS: at 90.56% examples, 201419 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:55,118 : INFO : PROGRESS: at 90.89% examples, 201447 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:43:56,130 : INFO : PROGRESS: at 91.23% examples, 201486 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:57,149 : INFO : PROGRESS: at 91.55% examples, 201457 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:58,152 : INFO : PROGRESS: at 91.82% examples, 201343 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:43:59,157 : INFO : PROGRESS: at 92.11% examples, 201283 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:44:00,163 : INFO : PROGRESS: at 92.44% examples, 201296 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:44:01,177 : INFO : PROGRESS: at 92.77% examples, 201311 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:44:02,257 : INFO : PROGRESS: at 93.11% examples, 201291 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:44:03,265 : INFO : PROGRESS: at 93.45% examples, 201324 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:44:04,287 : INFO : PROGRESS: at 93.77% examples, 201309 words/s, in_qsize 8, out_qsize 1
# 2017-03-18 16:44:05,323 : INFO : PROGRESS: at 94.10% examples, 201297 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:44:06,340 : INFO : PROGRESS: at 94.44% examples, 201329 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:44:07,391 : INFO : PROGRESS: at 94.77% examples, 201316 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:44:08,410 : INFO : PROGRESS: at 95.13% examples, 201361 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:44:09,421 : INFO : PROGRESS: at 95.47% examples, 201370 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:44:10,440 : INFO : PROGRESS: at 95.83% examples, 201416 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:44:11,445 : INFO : PROGRESS: at 96.16% examples, 201425 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:44:12,479 : INFO : PROGRESS: at 96.47% examples, 201388 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:44:13,493 : INFO : PROGRESS: at 96.79% examples, 201374 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:44:14,501 : INFO : PROGRESS: at 97.12% examples, 201380 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:44:15,501 : INFO : PROGRESS: at 97.46% examples, 201416 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:44:16,503 : INFO : PROGRESS: at 97.78% examples, 201409 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:44:17,533 : INFO : PROGRESS: at 98.08% examples, 201362 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:44:18,539 : INFO : PROGRESS: at 98.42% examples, 201382 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:44:19,560 : INFO : PROGRESS: at 98.75% examples, 201373 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:44:20,597 : INFO : PROGRESS: at 99.09% examples, 201398 words/s, in_qsize 7, out_qsize 0
# 2017-03-18 16:44:21,597 : INFO : PROGRESS: at 99.44% examples, 201423 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:44:22,640 : INFO : PROGRESS: at 99.79% examples, 201451 words/s, in_qsize 8, out_qsize 0
# 2017-03-18 16:44:23,161 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-03-18 16:44:23,203 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-03-18 16:44:23,220 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-03-18 16:44:23,258 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-03-18 16:44:23,259 : INFO : training on 85026035 raw words (62530955 effective words) took 310.4s, 201472 effective words/s
# 2017-03-18 16:44:23,260 : INFO : saving Word2Vec object under /home/sam/Data/twitter_sentiment/wordvec/tweets500.model.bin, separately None
# 2017-03-18 16:44:23,261 : INFO : not storing attribute syn0norm
# 2017-03-18 16:44:23,261 : INFO : storing np array 'syn0' to /home/sam/Data/twitter_sentiment/wordvec/tweets500.model.bin.wv.syn0.npy
# 2017-03-18 16:44:23,329 : INFO : storing np array 'syn1neg' to /home/sam/Data/twitter_sentiment/wordvec/tweets500.model.bin.syn1neg.npy
# 2017-03-18 16:44:23,394 : INFO : not storing attribute cum_table
# 2017-03-18 16:44:24,035 : INFO : saved /home/sam/Data/twitter_sentiment/wordvec/tweets500.model.bin
# 2017-03-18 16:44:24,036 : INFO : precomputing L2-norms of word weight vectors
# Done building.

# %%
# max_len is the max length of a sentence in our data, this decides the padding
max_len = airline_data.max_len(airline_df)
# convert our aline data to vector
data = airline_data.convert2vec(airline_df, max_len, model, name='airline500')
airline_data.save_vec(data, name='airline500')
# Out:
# max sentence length is:  21
# npy already exists, loading ...
# Done loading npy file.
# npy already exists.

# %%
# you can uncomment this to check if the wordvec makes sense
# model.wv.most_similar(positive=['woman', 'king'], negative=['man'])

# %%
N, M, D = data.shape
print "N, M, D:", N, M, D
data = data.reshape(-1, 1, M, D).astype(theano.config.floatX) # theano needs this way
label = airline_df['class']
label = np.int8(label) - 1# seems like theano also needs this
print data.shape
print label.shape
# Out:
# N, M, D: 8561 21 500
# (8561, 1, 21, 500)
# (8561,)

# %%
# ############################# Batch iterator ###############################
def iterate_minibatches(inputs, targets, batchsize, shuffle=False):
    assert len(inputs) == len(targets)
    if shuffle:
        indices = np.arange(len(inputs))
        np.random.shuffle(indices)
    for start_idx in range(0, len(inputs) - batchsize + 1, batchsize):
        if shuffle:
            excerpt = indices[start_idx:start_idx + batchsize]
        else:
            excerpt = slice(start_idx, start_idx + batchsize)
        yield inputs[excerpt], targets[excerpt]

# %%
# ##################### Build the CNN neural network model #######################
def build_cnn(input_var=None):
    # We create a CNN of two convolution + pooling stages
    # and a fully-connected hidden layer in front of the output layer.

    # Input layer, as usual:
    network = lasagne.layers.InputLayer(shape=(None, 1, M, D), input_var=input_var)
    # This time we do not apply input dropout, as it tends to work less well
    # for convolutional layers.
# first convolution layer
    # Convolutional layer with 32 kernels of size 3x3. Strided and padded
    # convolutions are supported as well; see the docstring.
    network = lasagne.layers.Conv2DLayer(network, num_filters=40, filter_size=(3, 5), \
                                         nonlinearity=lasagne.nonlinearities.rectify, \
                                         W=lasagne.init.GlorotUniform(), pad=0, stride=(1, 1), \
                                         untie_biases=True)
    # Max-pooling layer of factor 2 in both dimensions:
    network = lasagne.layers.MaxPool2DLayer(network, pool_size=(2, 2))
# second convolution layer
    # Another convolution with 32 3x3 kernels, and another 2x2 pooling:
#     network = lasagne.layers.Conv2DLayer(network, num_filters=40, filter_size=(3, 5), \
#                                          nonlinearity=lasagne.nonlinearities.rectify, pad=0, \
#                                          stride=(1, 1), untie_biases=True)
    
#     network = lasagne.layers.MaxPool2DLayer(network, pool_size=(2, 2))

    # A fully-connected layer of ??? units with 50% dropout on its inputs:
    network = lasagne.layers.DenseLayer(lasagne.layers.dropout(network, p=0.5), num_units=1000, \
                                        nonlinearity=lasagne.nonlinearities.rectify)

    # And, finally, the 10-unit output layer with 50% dropout on its inputs:
    network = lasagne.layers.DenseLayer(lasagne.layers.dropout(network, p=0.5), num_units=3,  \
                                        nonlinearity=lasagne.nonlinearities.softmax)

    return network

# %%
# ############################## Main program ################################
def train_cnn(X_train, y_train, X_val, y_val, X_test, num_epochs=300):
    # Load the dataset
    print("Loading data...")
    #X_train, y_train, X_val, y_val, X_test = load_dataset()
    # Prepare Theano variables for inputs and targets
    input_var = T.tensor4('inputs')
    target_var = T.ivector('targets')

    # Create neural network model (depending on first command line parameter)
    print("Building model and compiling functions...")

    network = build_cnn(input_var)
    accuracy_rate = []

    # Create a loss expression for training, i.e., a scalar objective we want
    # to minimize (for our multi-class problem, it is the cross-entropy loss):
    prediction = lasagne.layers.get_output(network)
    loss = lasagne.objectives.categorical_crossentropy(prediction, target_var)
    loss = loss.mean()
    # We could add some weight decay as well here, see lasagne.regularization.

    # Create update expressions for training, i.e., how to modify the
    # parameters at each training step. Here, we'll use Stochastic Gradient
    # Descent (SGD) with Nesterov momentum, but Lasagne offers plenty more.
    params = lasagne.layers.get_all_params(network, trainable=True)
    updates = lasagne.updates.nesterov_momentum(loss, params, learning_rate=0.005, momentum=0.9)

    # Create a loss expression for validation/testing. The crucial difference
    # here is that we do a deterministic forward pass through the network,
    # disabling dropout layers.
    test_prediction = lasagne.layers.get_output(network, deterministic=True)
    # print test_prediction.flatten()
    test_loss = lasagne.objectives.categorical_crossentropy(test_prediction, target_var)
    test_loss = test_loss.mean()
    # As a bonus, also create an expression for the classification accuracy:
    test_acc = T.mean(T.eq(T.argmax(test_prediction, axis=1), target_var), dtype=theano.config.floatX)

    predict_label = T.argmax(test_prediction,axis=1)

    # Compile a function performing a training step on a mini-batch (by giving
    # the updates dictionary) and returning the corresponding training loss:
    train_fn = theano.function([input_var, target_var], loss, updates=updates)

    # Compile a second function computing the validation loss and accuracy:
    val_fn = theano.function([input_var, target_var], [test_loss, test_acc])
    test_fn = theano.function([input_var], predict_label)

    # Finally, launch the training loop.
    print("Starting training...")
    # We iterate over epochs:
    for epoch in range(num_epochs):
#         start_time = time.time()
        # In each epoch, we do a full pass over the training data:
        train_err = 0
        train_batches = 0
        start_time = time.time()
        for batch in iterate_minibatches(X_train, y_train, 50, shuffle=True):
            inputs, targets = batch
            train_err += train_fn(inputs, targets)
            train_batches += 1
    
#         train_err = train_fn(X_train, y_train)
        # And a full pass over the validation data:
        val_err = 0
        val_acc = 0
        val_batches = 0
        for batch in iterate_minibatches(X_val, y_val, 50, shuffle=False):
            inputs, targets = batch
            err, acc = val_fn(inputs, targets)
            val_err += err
            val_acc += acc
            val_batches += 1
    
#         val_err, val_acc = val_fn(X_val, y_val)
#         accuracy_rate.append(val_acc)
        # Then we print the results for this epoch:
        print("Epoch {} of {} took {:.3f}s".format(epoch + 1, num_epochs, time.time() - start_time))
        print("  training loss:\t\t{:.6f}".format(train_err / train_batches))
        print("  validation loss:\t\t{:.6f}".format(val_err / val_batches))
        print("  validation accuracy:\t\t{:.2f} %".format(val_acc / val_batches * 100))

            
    # After training, we compute and print the test error:
    test_pred = test_fn(X_test[:50,:,:])
    print set(test_pred)

    # After training, we compute and print the test error:
#     test_err = 0
#     test_acc = 0
#     test_batches = 0
#     for batch in iterate_minibatches(X_test, y_test, 500, shuffle=False):
#         inputs, targets = batch
#         err, acc = val_fn(inputs, targets)
#         test_err += err
#         test_acc += acc
#         test_batches += 1
#     print("Final results:")
#     print("  test loss:\t\t\t{:.6f}".format(test_err / test_batches))
#     print("  test accuracy:\t\t{:.2f} %".format(
#         test_acc / test_batches * 100))

    # Optionally, you could now dump the network weights to a file like this:
    # np.savez('model.npz', *lasagne.layers.get_all_param_values(network))
    #
    # And load them again later on like this:
    # with np.load('model.npz') as f:
    #     param_values = [f['arr_%d' % i] for i in range(len(f.files))]
    # lasagne.layers.set_all_param_values(network, param_values)
    return test_pred

# %%
# stratified k-fold cross-validation
skf = StratifiedKFold(n_splits=3)
for train_index, val_index in skf.split(data, label):
    print("TRAIN:", train_index, "TEST:", val_index)
    data_train, data_val = data[train_index], data[val_index]
    label_train, label_val = label[train_index], label[val_index]
    
    freq_train = itemfreq(label_train)
    print "train freq", freq_train[:,1]
    freq_val = itemfreq(label_val)
    print "val freq", freq_val[:,1]
    
    train_cnn(data_train, label_train, data_val, label_val, data_val)
# Out:
# ('TRAIN:', array([2842, 2844, 2845, ..., 8558, 8559, 8560]), 'TEST:', array([   0,    1,    2, ..., 2872, 2876, 2877]))
# train freq [1575 2066 2066]
# val freq [ 788 1033 1033]
# Loading data...
# Building model and compiling functions...
# Starting training...
# Epoch 1 of 300 took 13.053s
#   training loss:		0.361240
#   validation loss:		0.354349
#   validation accuracy:		16.53 %
# Epoch 2 of 300 took 13.013s
#   training loss:		0.350905
#   validation loss:		0.350523
#   validation accuracy:		16.39 %
# Epoch 3 of 300 took 13.051s
#   training loss:		0.345920
#   validation loss:		0.348370
#   validation accuracy:		16.35 %
# Epoch 4 of 300 took 13.019s
#   training loss:		0.340658
#   validation loss:		0.343858
#   validation accuracy:		16.63 %
# Epoch 5 of 300 took 13.119s
#   training loss:		0.333680
#   validation loss:		0.337235
#   validation accuracy:		17.16 %
# -----------------------------------------------------------------------
# KeyboardInterrupt                     Traceback (most recent call last)
# <ipython-input-15-43ba018e1687> in <module>()
#      11     print "val freq", freq_val[:,1]
#      12
# ---> 13     train_cnn(data_train, label_train, data_val, label_val, data_val)
#
# <ipython-input-14-f1c92f8ba6ca> in train_cnn(X_train, y_train, X_val, y_val, X_test, num_epochs)
#      58         for batch in iterate_minibatches(X_train, y_train, 50, shuffle=True):
#      59             inputs, targets = batch
# ---> 60             train_err += train_fn(inputs, targets)
#      61             train_batches += 1
#      62
#
# /home/sam/anaconda2/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     882         try:
#     883             outputs =\
# --> 884                 self.fn() if output_subset is None else\
#     885                 self.fn(output_subset=output_subset)
#     886         except Exception:
#
# KeyboardInterrupt:
