# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import time
from scipy.stats import itemfreq

import theano
import theano.tensor as T
import lasagne
from sklearn.model_selection import StratifiedKFold


FILE_PATH = '/home/sam/Hhd/twitter_sentiment/'
# FILE_PATH = '/home/sam/Data/twitter_sentiment/'
# Out:
# Using cuDNN version 5105 on context None
# Mapped name None to device cuda: GeForce GTX 1080 (0000:01:00.0)

# %%
# laod data
pos_array = np.load(FILE_PATH+'pos.npy')
neg_array = np.load(FILE_PATH+'neg.npy')

# %%
print pos_array.shape
print neg_array.shape
data = np.concatenate([pos_array, neg_array])
N, M, D = data.shape
data = data.reshape(-1, 1, M, D).astype(theano.config.floatX)
label = np.concatenate([np.ones(pos_array.shape[0]), np.ones(neg_array.shape[0])+1]) # 1 for positive, 2 for negative
label = np.int8(label)-1
print data.shape
print label.shape
# Out:
# (2183, 20, 100)
# (2416, 20, 100)
# (4599, 1, 20, 100)
# (4599,)

# %%
# ##################### Build the CNN neural network model #######################
def build_cnn(input_var=None):
    # We create a CNN of two convolution + pooling stages
    # and a fully-connected hidden layer in front of the output layer.

    # Input layer, as usual:
    network = lasagne.layers.InputLayer(shape=(None, 1, M, D), input_var=input_var)
    # This time we do not apply input dropout, as it tends to work less well
    # for convolutional layers.

    # Convolutional layer with 32 kernels of size 3x3. Strided and padded
    # convolutions are supported as well; see the docstring.
    network = lasagne.layers.Conv2DLayer(network, num_filters=32, filter_size=(3, 3), \
                                         nonlinearity=lasagne.nonlinearities.rectify, \
                                         W=lasagne.init.GlorotUniform(), pad=1, stride=(1, 1), \
                                         untie_biases=True)
    # Max-pooling layer of factor 2 in both dimensions:
    network = lasagne.layers.MaxPool2DLayer(network, pool_size=(2, 2))

    # Another convolution with 32 3x3 kernels, and another 2x2 pooling:
    network = lasagne.layers.Conv2DLayer(network, num_filters=32, filter_size=(3, 3), \
                                         nonlinearity=lasagne.nonlinearities.rectify, pad=1, \
                                         stride=(1, 1), untie_biases=True)
    
    network = lasagne.layers.MaxPool2DLayer(network, pool_size=(2, 2))

    # A fully-connected layer of ??? units with 50% dropout on its inputs:
    network = lasagne.layers.DenseLayer(lasagne.layers.dropout(network, p=0.1), num_units=600, \
                                        nonlinearity=lasagne.nonlinearities.rectify)

    # And, finally, the 10-unit output layer with 50% dropout on its inputs:
    network = lasagne.layers.DenseLayer(lasagne.layers.dropout(network, p=0.1), num_units=2,  \
                                        nonlinearity=lasagne.nonlinearities.softmax)

    return network

# %%
# ############################## Main program ################################
def train_cnn(X_train, y_train, X_val, y_val, X_test, num_epochs=500):
    # Load the dataset
    print("Loading data...")
    #X_train, y_train, X_val, y_val, X_test = load_dataset()
    # Prepare Theano variables for inputs and targets
    input_var = T.tensor4('inputs')
    target_var = T.ivector('targets')

    # Create neural network model (depending on first command line parameter)
    print("Building model and compiling functions...")

    network = build_cnn(input_var)
    accuracy_rate = []

    # Create a loss expression for training, i.e., a scalar objective we want
    # to minimize (for our multi-class problem, it is the cross-entropy loss):
    prediction = lasagne.layers.get_output(network)
    loss = lasagne.objectives.categorical_crossentropy(prediction, target_var)
    loss = loss.mean()
    # We could add some weight decay as well here, see lasagne.regularization.

    # Create update expressions for training, i.e., how to modify the
    # parameters at each training step. Here, we'll use Stochastic Gradient
    # Descent (SGD) with Nesterov momentum, but Lasagne offers plenty more.
    params = lasagne.layers.get_all_params(network, trainable=True)
    updates = lasagne.updates.nesterov_momentum(loss, params, learning_rate=0.05, momentum=0.9)

    # Create a loss expression for validation/testing. The crucial difference
    # here is that we do a deterministic forward pass through the network,
    # disabling dropout layers.
    test_prediction = lasagne.layers.get_output(network, deterministic=True)
    # print test_prediction.flatten()
    test_loss = lasagne.objectives.categorical_crossentropy(test_prediction, target_var)
    test_loss = test_loss.mean()
    # As a bonus, also create an expression for the classification accuracy:
    test_acc = T.mean(T.eq(T.argmax(test_prediction, axis=1), target_var), dtype=theano.config.floatX)

    predict_label = T.argmax(test_prediction,axis=1)

    # Compile a function performing a training step on a mini-batch (by giving
    # the updates dictionary) and returning the corresponding training loss:
    train_fn = theano.function([input_var, target_var], loss, updates=updates)

    # Compile a second function computing the validation loss and accuracy:
    val_fn = theano.function([input_var, target_var], [test_loss, test_acc])
    test_fn = theano.function([input_var], predict_label)

    # Finally, launch the training loop.
    print("Starting training...")
    # We iterate over epochs:
    for epoch in range(num_epochs):
        start_time = time.time()
        # In each epoch, we do a full pass over the training data:
        train_err = train_fn(X_train, y_train)
        # And a full pass over the validation data:
        val_err, val_acc = val_fn(X_val, y_val)
        accuracy_rate.append(val_acc)
        # Then we print the results for this epoch:
        print("Epoch {} of {} took {:.3f}s".format(epoch + 1, num_epochs, time.time() - start_time))
        print("  training loss:\t\t{}".format(train_err))
        print("  validation loss:\t\t{}".format(val_err))
        print("  validation accuracy:\t\t{} %".format(val_acc * 100))
            
        # After training, we compute and print the test error:
        test_pred = test_fn(X_test)
#         print set(test_pred)

    return test_pred

# %%
# stratified k-fold cross-validation
skf = StratifiedKFold(n_splits=3)
for train_index, val_index in skf.split(data, label):
    print("TRAIN:", train_index, "TEST:", val_index)
    data_train, data_val = data[train_index], data[val_index]
    label_train, label_val = label[train_index], label[val_index]
    
    freq_train = itemfreq(label_train)
    print "train freq", freq_train[:,1]
    freq_val = itemfreq(label_val)
    print "val freq", freq_val[:,1]
    
    train_cnn(data_train, label_train, data_val, label_val, data_val)
# Out:
# ('TRAIN:', array([ 728,  729,  730, ..., 4596, 4597, 4598]), 'TEST:', array([   0,    1,    2, ..., 2986, 2987, 2988]))
# train freq [1455 1610]
# val freq [728 806]
# Loading data...
# Building model and compiling functions...
# Starting training...
# Epoch 1 of 500 took 0.149s
#   training loss:		0.693222939968
#   validation loss:		0.692399740219
#   validation accuracy:		53.1290769577 %
# Epoch 2 of 500 took 0.151s
#   training loss:		0.692976415157
#   validation loss:		0.692079126835
#   validation accuracy:		52.7379393578 %
# Epoch 3 of 500 took 0.146s
#   training loss:		0.692907512188
#   validation loss:		0.691745102406
#   validation accuracy:		53.3246397972 %
# Epoch 4 of 500 took 0.148s
#   training loss:		0.692195653915
#   validation loss:		0.691441178322
#   validation accuracy:		52.9986977577 %
# Epoch 5 of 500 took 0.144s
#   training loss:		0.692115008831
#   validation loss:		0.691190600395
#   validation accuracy:		52.3468077183 %
# Epoch 6 of 500 took 0.148s
#   training loss:		0.691323578358
#   validation loss:		0.690993189812
#   validation accuracy:		52.5423705578 %
# Epoch 7 of 500 took 0.144s
#   training loss:		0.691116213799
#   validation loss:		0.690832972527
#   validation accuracy:		52.5423705578 %
# Epoch 8 of 500 took 0.148s
#   training loss:		0.691055476665
#   validation loss:		0.690692663193
#   validation accuracy:		52.5423705578 %
# Epoch 9 of 500 took 0.145s
#   training loss:		0.690558552742
#   validation loss:		0.690561890602
#   validation accuracy:		52.5423705578 %
# Epoch 10 of 500 took 0.148s
#   training loss:		0.690165102482
#   validation loss:		0.690429389477
#   validation accuracy:		52.5423705578 %
# Epoch 11 of 500 took 0.145s
#   training loss:		0.689980208874
#   validation loss:		0.690290212631
#   validation accuracy:		52.4771809578 %
# Epoch 12 of 500 took 0.148s
#   training loss:		0.689572870731
#   validation loss:		0.690148055553
#   validation accuracy:		53.0638873577 %
# Epoch 13 of 500 took 0.145s
#   training loss:		0.689136683941
#   validation loss:		0.690013825893
#   validation accuracy:		53.5853981972 %
# Epoch 14 of 500 took 0.149s
#   training loss:		0.68903619051
#   validation loss:		0.689890325069
#   validation accuracy:		53.7809669971 %
# Epoch 15 of 500 took 0.144s
#   training loss:		0.68857395649
#   validation loss:		0.689777076244
#   validation accuracy:		53.8461565971 %
# Epoch 16 of 500 took 0.147s
#   training loss:		0.688565313816
#   validation loss:		0.689674437046
#   validation accuracy:		53.9113402367 %
# Epoch 17 of 500 took 0.145s
#   training loss:		0.687830805779
#   validation loss:		0.689582407475
#   validation accuracy:		54.6936094761 %
# Epoch 18 of 500 took 0.148s
#   training loss:		0.687728762627
#   validation loss:		0.689500391483
#   validation accuracy:		54.5632362366 %
# Epoch 19 of 500 took 0.145s
#   training loss:		0.68741196394
#   validation loss:		0.689422905445
#   validation accuracy:		54.8239886761 %
# Epoch 20 of 500 took 0.149s
#   training loss:		0.687039256096
#   validation loss:		0.689343690872
#   validation accuracy:		54.5632362366 %
# Epoch 21 of 500 took 0.145s
#   training loss:		0.687119722366
#   validation loss:		0.689267933369
#   validation accuracy:		54.4980466366 %
# Epoch 22 of 500 took 0.149s
#   training loss:		0.686649858952
#   validation loss:		0.689190924168
#   validation accuracy:		54.3024778366 %
# Epoch 23 of 500 took 0.145s
#   training loss:		0.686314821243
#   validation loss:		0.689115941525
#   validation accuracy:		54.1069090366 %
# Epoch 24 of 500 took 0.148s
#   training loss:		0.686063110828
#   validation loss:		0.68904209137
#   validation accuracy:		54.1720986366 %
# Epoch 25 of 500 took 0.145s
#   training loss:		0.685996115208
#   validation loss:		0.688971817493
#   validation accuracy:		54.6284198761 %
# Epoch 26 of 500 took 0.148s
#   training loss:		0.685623824596
#   validation loss:		0.68890017271
#   validation accuracy:		54.4980466366 %
# Epoch 27 of 500 took 0.144s
#   training loss:		0.685250818729
#   validation loss:		0.688832342625
#   validation accuracy:		54.4980466366 %
# Epoch 28 of 500 took 0.149s
#   training loss:		0.685533881187
#   validation loss:		0.688765585423
#   validation accuracy:		54.7587990761 %
# Epoch 29 of 500 took 0.144s
#   training loss:		0.684869468212
#   validation loss:		0.688698649406
#   validation accuracy:		54.4328570366 %
# Epoch 30 of 500 took 0.148s
#   training loss:		0.684745013714
#   validation loss:		0.688629984856
#   validation accuracy:		54.1069090366 %
# Epoch 31 of 500 took 0.145s
#   training loss:		0.684416353703
#   validation loss:		0.688558340073
#   validation accuracy:		54.1069090366 %
# Epoch 32 of 500 took 0.148s
#   training loss:		0.68402916193
#   validation loss:		0.688485860825
#   validation accuracy:		54.2372882366 %
# Epoch 33 of 500 took 0.145s
#   training loss:		0.683777928352
#   validation loss:		0.688411056995
#   validation accuracy:		54.4980466366 %
# Epoch 34 of 500 took 0.150s
#   training loss:		0.683698713779
#   validation loss:		0.68833398819
#   validation accuracy:		53.9765298367 %
# Epoch 35 of 500 took 0.146s
#   training loss:		0.683461904526
#   validation loss:		0.688255667686
#   validation accuracy:		53.8461565971 %
# Epoch 36 of 500 took 0.149s
#   training loss:		0.683429181576
#   validation loss:		0.688174903393
#   validation accuracy:		53.7809669971 %
# Epoch 37 of 500 took 0.144s
#   training loss:		0.683080792427
#   validation loss:		0.688089966774
#   validation accuracy:		53.7157773972 %
# Epoch 38 of 500 took 0.148s
#   training loss:		0.682985007763
#   validation loss:		0.688000559807
#   validation accuracy:		53.5853981972 %
# Epoch 39 of 500 took 0.145s
#   training loss:		0.682474851608
#   validation loss:		0.687906622887
#   validation accuracy:		53.4550189972 %
# Epoch 40 of 500 took 0.149s
#   training loss:		0.68204665184
#   validation loss:		0.68780952692
#   validation accuracy:		53.5202085972 %
# Epoch 41 of 500 took 0.145s
#   training loss:		0.681950092316
#   validation loss:		0.687710702419
#   validation accuracy:		53.6505877972 %
# Epoch 42 of 500 took 0.149s
#   training loss:		0.682081699371
#   validation loss:		0.687604784966
#   validation accuracy:		53.7157773972 %
# Epoch 43 of 500 took 0.145s
#   training loss:		0.681778371334
#   validation loss:		0.687495231628
#   validation accuracy:		54.2372882366 %
# Epoch 44 of 500 took 0.148s
#   training loss:		0.681280851364
#   validation loss:		0.687380731106
#   validation accuracy:		54.2372882366 %
# Epoch 45 of 500 took 0.145s
#   training loss:		0.68117505312
#   validation loss:		0.687263906002
#   validation accuracy:		54.9543678761 %
# Epoch 46 of 500 took 0.149s
#   training loss:		0.680891871452
#   validation loss:		0.687145411968
#   validation accuracy:		54.8891782761 %
# Epoch 47 of 500 took 0.144s
#   training loss:		0.68064302206
#   validation loss:		0.687026023865
#   validation accuracy:		55.019557476 %
# Epoch 48 of 500 took 0.149s
#   training loss:		0.679935216904
#   validation loss:		0.686898946762
#   validation accuracy:		54.9543678761 %
# Epoch 49 of 500 took 0.145s
#   training loss:		0.679925441742
#   validation loss:		0.686767756939
#   validation accuracy:		55.084747076 %
# Epoch 50 of 500 took 0.148s
#   training loss:		0.679516494274
#   validation loss:		0.686634778976
#   validation accuracy:		55.215126276 %
# Epoch 51 of 500 took 0.145s
#   training loss:		0.679229795933
#   validation loss:		0.686497151852
#   validation accuracy:		55.280315876 %
# Epoch 52 of 500 took 0.148s
#   training loss:		0.679094552994
#   validation loss:		0.686358571053
#   validation accuracy:		55.149936676 %
# Epoch 53 of 500 took 0.145s
#   training loss:		0.678768754005
#   validation loss:		0.686215639114
#   validation accuracy:		55.215126276 %
# Epoch 54 of 500 took 0.149s
#   training loss:		0.678207278252
#   validation loss:		0.686063706875
#   validation accuracy:		55.215126276 %
# Epoch 55 of 500 took 0.144s
#   training loss:		0.678263604641
#   validation loss:		0.685907065868
#   validation accuracy:		55.215126276 %
# Epoch 56 of 500 took 0.149s
#   training loss:		0.677281618118
#   validation loss:		0.685745358467
#   validation accuracy:		55.215126276 %
# Epoch 57 of 500 took 0.145s
#   training loss:		0.677381157875
#   validation loss:		0.685581386089
#   validation accuracy:		55.215126276 %
# Epoch 58 of 500 took 0.148s
#   training loss:		0.677015244961
#   validation loss:		0.685411512852
#   validation accuracy:		55.4758787155 %
# Epoch 59 of 500 took 0.145s
#   training loss:		0.676774680614
#   validation loss:		0.685240030289
#   validation accuracy:		55.4106891155 %
# Epoch 60 of 500 took 0.148s
#   training loss:		0.676413238049
#   validation loss:		0.68506026268
#   validation accuracy:		55.7366371155 %
# Epoch 61 of 500 took 0.145s
#   training loss:		0.675937473774
#   validation loss:		0.684875071049
#   validation accuracy:		55.9322059155 %
# Epoch 62 of 500 took 0.149s
#   training loss:		0.675369918346
#   validation loss:		0.684685528278
#   validation accuracy:		56.1929583549 %
# Epoch 63 of 500 took 0.144s
#   training loss:		0.674872636795
#   validation loss:		0.684487164021
#   validation accuracy:		56.2581479549 %
# Epoch 64 of 500 took 0.148s
#   training loss:		0.674928545952
#   validation loss:		0.684285521507
#   validation accuracy:		56.127768755 %
# Epoch 65 of 500 took 0.146s
#   training loss:		0.674694895744
#   validation loss:		0.684076309204
#   validation accuracy:		56.127768755 %
# Epoch 66 of 500 took 0.148s
#   training loss:		0.674096226692
#   validation loss:		0.683859348297
#   validation accuracy:		56.127768755 %
# Epoch 67 of 500 took 0.145s
#   training loss:		0.673707544804
#   validation loss:		0.683636546135
#   validation accuracy:		56.1929583549 %
# Epoch 68 of 500 took 0.149s
#   training loss:		0.672868132591
#   validation loss:		0.683407366276
#   validation accuracy:		56.127768755 %
# Epoch 69 of 500 took 0.145s
#   training loss:		0.673046171665
#   validation loss:		0.683170557022
#   validation accuracy:		56.1929583549 %
# Epoch 70 of 500 took 0.148s
#   training loss:		0.672355413437
#   validation loss:		0.682928025723
#   validation accuracy:		56.1929583549 %
# Epoch 71 of 500 took 0.145s
#   training loss:		0.671887516975
#   validation loss:		0.682677686214
#   validation accuracy:		56.3233375549 %
# Epoch 72 of 500 took 0.147s
#   training loss:		0.671443521976
#   validation loss:		0.682417273521
#   validation accuracy:		56.6492855549 %
# Epoch 73 of 500 took 0.146s
#   training loss:		0.670858204365
#   validation loss:		0.68214815855
#   validation accuracy:		56.9752275944 %
# Epoch 74 of 500 took 0.149s
#   training loss:		0.670114696026
#   validation loss:		0.681871652603
#   validation accuracy:		56.8448483944 %
# Epoch 75 of 500 took 0.144s
#   training loss:		0.669643580914
#   validation loss:		0.681586027145
#   validation accuracy:		57.2359859943 %
# Epoch 76 of 500 took 0.149s
#   training loss:		0.669321656227
#   validation loss:		0.681292772293
#   validation accuracy:		57.3663651943 %
# Epoch 77 of 500 took 0.145s
#   training loss:		0.668690502644
#   validation loss:		0.680988729
#   validation accuracy:		57.8226864338 %
# Epoch 78 of 500 took 0.148s
#   training loss:		0.668453931808
#   validation loss:		0.680678069592
#   validation accuracy:		57.9530656338 %
# Epoch 79 of 500 took 0.145s
#   training loss:		0.667981922626
#   validation loss:		0.680353462696
#   validation accuracy:		58.2138180733 %
# Epoch 80 of 500 took 0.148s
#   training loss:		0.667008936405
#   validation loss:		0.680017113686
#   validation accuracy:		58.1486284733 %
# Epoch 81 of 500 took 0.145s
#   training loss:		0.666204810143
#   validation loss:		0.679671287537
#   validation accuracy:		58.0182552338 %
# Epoch 82 of 500 took 0.149s
#   training loss:		0.666127443314
#   validation loss:		0.679312109947
#   validation accuracy:		58.1486284733 %
# Epoch 83 of 500 took 0.145s
#   training loss:		0.664928495884
#   validation loss:		0.678945839405
#   validation accuracy:		58.1486284733 %
# Epoch 84 of 500 took 0.148s
#   training loss:		0.664273798466
#   validation loss:		0.678563892841
#   validation accuracy:		58.1486284733 %
# Epoch 85 of 500 took 0.145s
#   training loss:		0.663438737392
#   validation loss:		0.678171515465
#   validation accuracy:		58.3441972733 %
# Epoch 86 of 500 took 0.148s
#   training loss:		0.662996470928
#   validation loss:		0.677763402462
#   validation accuracy:		58.3441972733 %
# Epoch 87 of 500 took 0.146s
#   training loss:		0.662401914597
#   validation loss:		0.677347242832
#   validation accuracy:		58.4745764732 %
# Epoch 88 of 500 took 0.149s
#   training loss:		0.661258876324
#   validation loss:		0.676916480064
#   validation accuracy:		58.4093868732 %
# Epoch 89 of 500 took 0.144s
#   training loss:		0.660908162594
#   validation loss:		0.676467895508
#   validation accuracy:		58.5397660732 %
# Epoch 90 of 500 took 0.149s
#   training loss:		0.660218477249
#   validation loss:		0.676007330418
#   validation accuracy:		58.6049556732 %
# Epoch 91 of 500 took 0.144s
#   training loss:		0.658736586571
#   validation loss:		0.675527691841
#   validation accuracy:		58.5397660732 %
# Epoch 92 of 500 took 0.148s
#   training loss:		0.658373773098
#   validation loss:		0.675033628941
#   validation accuracy:		58.2790076733 %
# Epoch 93 of 500 took 0.145s
#   training loss:		0.65833979845
#   validation loss:		0.674521803856
#   validation accuracy:		58.1486284733 %
# Epoch 94 of 500 took 0.148s
#   training loss:		0.657264769077
#   validation loss:		0.673985421658
#   validation accuracy:		58.0834448338 %
# Epoch 95 of 500 took 0.144s
#   training loss:		0.656199634075
#   validation loss:		0.673440337181
#   validation accuracy:		58.0182552338 %
# Epoch 96 of 500 took 0.148s
#   training loss:		0.654930114746
#   validation loss:		0.67287927866
#   validation accuracy:		58.2790076733 %
# Epoch 97 of 500 took 0.144s
#   training loss:		0.653968393803
#   validation loss:		0.672296822071
#   validation accuracy:		58.3441972733 %
# Epoch 98 of 500 took 0.149s
#   training loss:		0.653607964516
#   validation loss:		0.671695530415
#   validation accuracy:		58.0834448338 %
# Epoch 99 of 500 took 0.144s
#   training loss:		0.651547372341
#   validation loss:		0.67107373476
#   validation accuracy:		58.2138180733 %
# Epoch 100 of 500 took 0.147s
#   training loss:		0.651069819927
#   validation loss:		0.670438349247
#   validation accuracy:		58.1486284733 %
# Epoch 101 of 500 took 0.145s
#   training loss:		0.649747371674
#   validation loss:		0.669789433479
#   validation accuracy:		58.3441972733 %
# Epoch 102 of 500 took 0.147s
#   training loss:		0.647665739059
#   validation loss:		0.669110417366
#   validation accuracy:		58.4745764732 %
# Epoch 103 of 500 took 0.145s
#   training loss:		0.647578001022
#   validation loss:		0.668406665325
#   validation accuracy:		58.8657081127 %
# Epoch 104 of 500 took 0.149s
#   training loss:		0.646997451782
#   validation loss:		0.66768181324
#   validation accuracy:		59.0612769127 %
# Epoch 105 of 500 took 0.144s
#   training loss:		0.644832074642
#   validation loss:		0.666932821274
#   validation accuracy:		58.6049556732 %
# Epoch 106 of 500 took 0.148s
#   training loss:		0.643363535404
#   validation loss:		0.666157484055
#   validation accuracy:		59.3220353127 %
# Epoch 107 of 500 took 0.144s
#   training loss:		0.642125248909
#   validation loss:		0.665359914303
#   validation accuracy:		59.3220353127 %
# Epoch 108 of 500 took 0.148s
#   training loss:		0.641180813313
#   validation loss:		0.664533913136
#   validation accuracy:		59.5827877522 %
# Epoch 109 of 500 took 0.145s
#   training loss:		0.638970673084
#   validation loss:		0.663680076599
#   validation accuracy:		59.6479773521 %
# Epoch 110 of 500 took 0.147s
#   training loss:		0.639108836651
#   validation loss:		0.662797093391
#   validation accuracy:		60.1043045521 %
# Epoch 111 of 500 took 0.145s
#   training loss:		0.638021409512
#   validation loss:		0.661901712418
#   validation accuracy:		59.8435461521 %
# Epoch 112 of 500 took 0.148s
#   training loss:		0.635198652744
#   validation loss:		0.660970747471
#   validation accuracy:		60.2346777916 %
# Epoch 113 of 500 took 0.144s
#   training loss:		0.632874011993
#   validation loss:		0.660000026226
#   validation accuracy:		60.7561945915 %
# Epoch 114 of 500 took 0.148s
#   training loss:		0.632875323296
#   validation loss:		0.659022510052
#   validation accuracy:		60.951757431 %
# Epoch 115 of 500 took 0.144s
#   training loss:		0.630286633968
#   validation loss:		0.658017039299
#   validation accuracy:		61.212515831 %
# Epoch 116 of 500 took 0.148s
#   training loss:		0.628721773624
#   validation loss:		0.656986534595
#   validation accuracy:		61.5384638309 %
# Epoch 117 of 500 took 0.145s
#   training loss:		0.626684904099
#   validation loss:		0.655937969685
#   validation accuracy:		61.8644058704 %
# Epoch 118 of 500 took 0.148s
#   training loss:		0.625488460064
#   validation loss:		0.654873847961
#   validation accuracy:		61.6036534309 %
# Epoch 119 of 500 took 0.145s
#   training loss:		0.623817384243
#   validation loss:		0.653774082661
#   validation accuracy:		62.0599746704 %
# Epoch 120 of 500 took 0.148s
#   training loss:		0.620880544186
#   validation loss:		0.652657628059
#   validation accuracy:		62.1251642704 %
# Epoch 121 of 500 took 0.144s
#   training loss:		0.61896443367
#   validation loss:		0.651507616043
#   validation accuracy:		62.2555434704 %
# Epoch 122 of 500 took 0.148s
#   training loss:		0.6189057827
#   validation loss:		0.650332391262
#   validation accuracy:		62.3207330704 %
# Epoch 123 of 500 took 0.144s
#   training loss:		0.614655792713
#   validation loss:		0.649137556553
#   validation accuracy:		62.5162959099 %
# Epoch 124 of 500 took 0.148s
#   training loss:		0.61394149065
#   validation loss:		0.647918343544
#   validation accuracy:		62.7770543098 %
# Epoch 125 of 500 took 0.145s
#   training loss:		0.61096739769
#   validation loss:		0.646701097488
#   validation accuracy:		62.6466751099 %
# Epoch 126 of 500 took 0.148s
#   training loss:		0.609980881214
#   validation loss:		0.645455420017
#   validation accuracy:		62.7770543098 %
# Epoch 127 of 500 took 0.145s
#   training loss:		0.606640219688
#   validation loss:		0.644206762314
#   validation accuracy:		62.7770543098 %
# Epoch 128 of 500 took 0.148s
#   training loss:		0.606704771519
#   validation loss:		0.642938911915
#   validation accuracy:		62.8422439098 %
# Epoch 129 of 500 took 0.145s
#   training loss:		0.603600263596
#   validation loss:		0.641676545143
#   validation accuracy:		62.9726231098 %
# Epoch 130 of 500 took 0.149s
#   training loss:		0.601405143738
#   validation loss:		0.640389740467
#   validation accuracy:		63.1681859493 %
# Epoch 131 of 500 took 0.144s
#   training loss:		0.597834765911
#   validation loss:		0.639082431793
#   validation accuracy:		63.4289443493 %
# Epoch 132 of 500 took 0.148s
#   training loss:		0.595580399036
#   validation loss:		0.637796580791
#   validation accuracy:		63.4289443493 %
# Epoch 133 of 500 took 0.145s
#   training loss:		0.593752324581
#   validation loss:		0.636490225792
#   validation accuracy:		63.4289443493 %
# Epoch 134 of 500 took 0.148s
#   training loss:		0.591720938683
#   validation loss:		0.63518601656
#   validation accuracy:		63.5593235493 %
# Epoch 135 of 500 took 0.145s
#   training loss:		0.589090526104
#   validation loss:		0.633880138397
#   validation accuracy:		63.4941339493 %
# Epoch 136 of 500 took 0.148s
#   training loss:		0.588021755219
#   validation loss:		0.632547795773
#   validation accuracy:		63.3637547493 %
# Epoch 137 of 500 took 0.145s
#   training loss:		0.584791362286
#   validation loss:		0.631260156631
#   validation accuracy:		63.4289443493 %
# Epoch 138 of 500 took 0.148s
#   training loss:		0.58455324173
#   validation loss:		0.629940807819
#   validation accuracy:		63.4289443493 %
# Epoch 139 of 500 took 0.144s
#   training loss:		0.578514814377
#   validation loss:		0.628659844398
#   validation accuracy:		63.3637547493 %
# Epoch 140 of 500 took 0.148s
#   training loss:		0.577376186848
#   validation loss:		0.627351999283
#   validation accuracy:		63.4941339493 %
# Epoch 141 of 500 took 0.145s
#   training loss:		0.573868691921
#   validation loss:		0.626103699207
#   validation accuracy:		63.1029963493 %
# Epoch 142 of 500 took 0.147s
#   training loss:		0.572570383549
#   validation loss:		0.624849498272
#   validation accuracy:		63.2333755493 %
# Epoch 143 of 500 took 0.145s
#   training loss:		0.5703343153
#   validation loss:		0.623677194118
#   validation accuracy:		63.3637547493 %
# Epoch 144 of 500 took 0.148s
#   training loss:		0.570236086845
#   validation loss:		0.622469723225
#   validation accuracy:		63.4289443493 %
# Epoch 145 of 500 took 0.145s
#   training loss:		0.566326618195
#   validation loss:		0.621330976486
#   validation accuracy:		63.6897027493 %
# Epoch 146 of 500 took 0.148s
#   training loss:		0.562882721424
#   validation loss:		0.620213329792
#   validation accuracy:		64.6023452282 %
# Epoch 147 of 500 took 0.144s
#   training loss:		0.559065461159
#   validation loss:		0.619132220745
#   validation accuracy:		63.4941339493 %
# Epoch 148 of 500 took 0.148s
#   training loss:		0.558078229427
#   validation loss:		0.618184804916
#   validation accuracy:		64.8631036282 %
# Epoch 149 of 500 took 0.145s
#   training loss:		0.553904414177
#   validation loss:		0.617002427578
#   validation accuracy:		64.4067823887 %
# Epoch 150 of 500 took 0.148s
#   training loss:		0.552643358707
#   validation loss:		0.615982890129
#   validation accuracy:		65.3194248676 %
# Epoch 151 of 500 took 0.145s
#   training loss:		0.549179196358
#   validation loss:		0.614825129509
#   validation accuracy:		64.6675348282 %
# Epoch 152 of 500 took 0.147s
#   training loss:		0.549016714096
#   validation loss:		0.613865494728
#   validation accuracy:		65.7757520676 %
# Epoch 153 of 500 took 0.144s
#   training loss:		0.547179698944
#   validation loss:		0.612764537334
#   validation accuracy:		65.1238620281 %
# Epoch 154 of 500 took 0.148s
#   training loss:		0.542708098888
#   validation loss:		0.611845552921
#   validation accuracy:		65.7105624676 %
# Epoch 155 of 500 took 0.145s
#   training loss:		0.538884758949
#   validation loss:		0.6108533144
#   validation accuracy:		65.1238620281 %
# Epoch 156 of 500 took 0.148s
#   training loss:		0.54019343853
#   validation loss:		0.610772490501
#   validation accuracy:		65.7757520676 %
# Epoch 157 of 500 took 0.145s
#   training loss:		0.535066664219
#   validation loss:		0.610749781132
#   validation accuracy:		64.0808343887 %
# Epoch 158 of 500 took 0.148s
#   training loss:		0.532996833324
#   validation loss:		0.613173544407
#   validation accuracy:		65.6453728676 %
# Epoch 159 of 500 took 0.145s
#   training loss:		0.532619297504
#   validation loss:		0.617719113827
#   validation accuracy:		63.2333755493 %
# Epoch 160 of 500 took 0.147s
#   training loss:		0.538575232029
#   validation loss:		0.637787044048
#   validation accuracy:		64.2112135887 %
# Epoch 161 of 500 took 0.145s
#   training loss:		0.552351772785
#   validation loss:		0.693935751915
#   validation accuracy:		60.2998673916 %
# Epoch 162 of 500 took 0.149s
#   training loss:		0.611389696598
#   validation loss:		0.82799834013
#   validation accuracy:		51.6949176788 %
# Epoch 163 of 500 took 0.144s
#   training loss:		0.732744395733
#   validation loss:		1.02657008171
#   validation accuracy:		53.7809669971 %
# Epoch 164 of 500 took 0.148s
#   training loss:		0.929198563099
#   validation loss:		0.865753829479
#   validation accuracy:		49.4132995605 %
# Epoch 165 of 500 took 0.144s
#   training loss:		0.770352184772
#   validation loss:		0.810529947281
#   validation accuracy:		56.9752275944 %
# Epoch 166 of 500 took 0.148s
#   training loss:		0.726815223694
#   validation loss:		0.682718515396
#   validation accuracy:		58.8005244732 %
# Epoch 167 of 500 took 0.144s
#   training loss:		0.598913311958
#   validation loss:		0.631269574165
#   validation accuracy:		63.4941339493 %
# Epoch 168 of 500 took 0.147s
#   training loss:		0.554220616817
#   validation loss:		0.614056706429
#   validation accuracy:		66.1016941071 %
# Epoch 169 of 500 took 0.146s
#   training loss:		0.536638915539
#   validation loss:		0.608148276806
#   validation accuracy:		66.297262907 %
# Epoch 170 of 500 took 0.148s
#   training loss:		0.5321585536
#   validation loss:		0.607381224632
#   validation accuracy:		66.232073307 %
# Epoch 171 of 500 took 0.145s
#   training loss:		0.533984363079
#   validation loss:		0.606625139713
#   validation accuracy:		66.166883707 %
# Epoch 172 of 500 took 0.149s
#   training loss:		0.531592547894
#   validation loss:		0.605608701706
#   validation accuracy:		66.166883707 %
# Epoch 173 of 500 took 0.144s
#   training loss:		0.528851270676
#   validation loss:		0.604378163815
#   validation accuracy:		66.166883707 %
# Epoch 174 of 500 took 0.148s
#   training loss:		0.526231884956
#   validation loss:		0.603047132492
#   validation accuracy:		66.5580153465 %
# Epoch 175 of 500 took 0.144s
#   training loss:		0.523162066936
#   validation loss:		0.601745009422
#   validation accuracy:		66.7535841465 %
# Epoch 176 of 500 took 0.148s
#   training loss:		0.518569052219
#   validation loss:		0.600486397743
#   validation accuracy:		66.9491529465 %
# Epoch 177 of 500 took 0.146s
#   training loss:		0.515944004059
#   validation loss:		0.599276125431
#   validation accuracy:		67.0143425465 %
# Epoch 178 of 500 took 0.147s
#   training loss:		0.514623522758
#   validation loss:		0.598149120808
#   validation accuracy:		67.0143425465 %
# Epoch 179 of 500 took 0.145s
#   training loss:		0.509702801704
#   validation loss:		0.597130715847
#   validation accuracy:		67.340284586 %
# Epoch 180 of 500 took 0.148s
#   training loss:		0.506393790245
#   validation loss:		0.596181750298
#   validation accuracy:		67.4706637859 %
# Epoch 181 of 500 took 0.144s
#   training loss:		0.503265917301
#   validation loss:		0.595341920853
#   validation accuracy:		67.5358533859 %
# Epoch 182 of 500 took 0.148s
#   training loss:		0.498186349869
#   validation loss:		0.5943775177
#   validation accuracy:		67.7966117859 %
# Epoch 183 of 500 took 0.145s
#   training loss:		0.49727666378
#   validation loss:		0.593596041203
#   validation accuracy:		67.340284586 %
# Epoch 184 of 500 took 0.147s
#   training loss:		0.495101541281
#   validation loss:		0.592733740807
#   validation accuracy:		67.4706637859 %
# Epoch 185 of 500 took 0.146s
#   training loss:		0.492700517178
#   validation loss:		0.591904163361
#   validation accuracy:		67.6662325859 %
# Epoch 186 of 500 took 0.148s
#   training loss:		0.49084559083
#   validation loss:		0.591358661652
#   validation accuracy:		67.0795321465 %
# Epoch 187 of 500 took 0.145s
#   training loss:		0.48866584897
#   validation loss:		0.591040790081
#   validation accuracy:		68.3833122253 %
# Epoch 188 of 500 took 0.149s
#   training loss:		0.486527591944
#   validation loss:		0.591097891331
#   validation accuracy:		67.0143425465 %
# Epoch 189 of 500 took 0.144s
#   training loss:		0.481460094452
#   validation loss:		0.592924296856
#   validation accuracy:		68.1225538254 %
# Epoch 190 of 500 took 0.148s
#   training loss:		0.48256829381
#   validation loss:		0.599476754665
#   validation accuracy:		65.9713149071 %
# Epoch 191 of 500 took 0.144s
#   training loss:		0.486598312855
#   validation loss:		0.624130964279
#   validation accuracy:		66.232073307 %
# Epoch 192 of 500 took 0.148s
#   training loss:		0.507871866226
#   validation loss:		0.696256279945
#   validation accuracy:		61.277705431 %
# Epoch 193 of 500 took 0.145s
#   training loss:		0.576080143452
#   validation loss:		0.85021007061
#   validation accuracy:		51.8904805183 %
# Epoch 194 of 500 took 0.148s
#   training loss:		0.715132594109
#   validation loss:		1.11836385727
#   validation accuracy:		55.215126276 %
# Epoch 195 of 500 took 0.145s
#   training loss:		0.977699398994
#   validation loss:		0.857466459274
#   validation accuracy:		51.1734008789 %
# Epoch 196 of 500 took 0.149s
#   training loss:		0.721940815449
#   validation loss:		0.83201789856
#   validation accuracy:		57.8878760338 %
# Epoch 197 of 500 took 0.144s
#   training loss:		0.706576645374
#   validation loss:		0.683211684227
#   validation accuracy:		60.4302465916 %
# Epoch 198 of 500 took 0.148s
#   training loss:		0.567487955093
#   validation loss:		0.630574643612
#   validation accuracy:		63.3637547493 %
# Epoch 199 of 500 took 0.145s
#   training loss:		0.521558046341
#   validation loss:		0.602946519852
#   validation accuracy:		67.340284586 %
# Epoch 200 of 500 took 0.147s
#   training loss:		0.497620642185
#   validation loss:		0.591753840446
#   validation accuracy:		66.6232049465 %
# Epoch 201 of 500 took 0.146s
#   training loss:		0.48873141408
#   validation loss:		0.590008616447
#   validation accuracy:		68.4485018253 %
# Epoch 202 of 500 took 0.148s
#   training loss:		0.488229781389
#   validation loss:		0.588664889336
#   validation accuracy:		68.4485018253 %
# Epoch 203 of 500 took 0.145s
#   training loss:		0.485648006201
#   validation loss:		0.587604284286
#   validation accuracy:		68.3181226254 %
# Epoch 204 of 500 took 0.148s
#   training loss:		0.48115131259
#   validation loss:		0.586408495903
#   validation accuracy:		68.7744438648 %
# Epoch 205 of 500 took 0.144s
#   training loss:		0.477348446846
#   validation loss:		0.585209727287
#   validation accuracy:		68.8396334648 %
# Epoch 206 of 500 took 0.148s
#   training loss:		0.47066539526
#   validation loss:		0.584086835384
#   validation accuracy:		68.6440706253 %
# Epoch 207 of 500 took 0.145s
#   training loss:		0.466560810804
#   validation loss:		0.583118259907
#   validation accuracy:		68.6440706253 %
# Epoch 208 of 500 took 0.148s
#   training loss:		0.463648289442
#   validation loss:		0.582364678383
#   validation accuracy:		69.0352022648 %
# Epoch 209 of 500 took 0.145s
#   training loss:		0.458555996418
#   validation loss:		0.581586122513
#   validation accuracy:		68.6440706253 %
# Epoch 210 of 500 took 0.148s
#   training loss:		0.45343130827
#   validation loss:		0.581022143364
#   validation accuracy:		69.3611502647 %
# Epoch 211 of 500 took 0.144s
#   training loss:		0.449458509684
#   validation loss:		0.58039277792
#   validation accuracy:		68.7744438648 %
# Epoch 212 of 500 took 0.148s
#   training loss:		0.446377426386
#   validation loss:		0.58064776659
#   validation accuracy:		68.9700126648 %
# Epoch 213 of 500 took 0.144s
#   training loss:		0.445257723331
#   validation loss:		0.580083012581
#   validation accuracy:		68.4485018253 %
# Epoch 214 of 500 took 0.149s
#   training loss:		0.444809377193
#   validation loss:		0.581326246262
#   validation accuracy:		68.9700126648 %
# Epoch 215 of 500 took 0.145s
#   training loss:		0.440777331591
#   validation loss:		0.583998322487
#   validation accuracy:		67.5358533859 %
# Epoch 216 of 500 took 0.147s
#   training loss:		0.443882226944
#   validation loss:		0.597525060177
#   validation accuracy:		68.7744438648 %
# Epoch 217 of 500 took 0.146s
#   training loss:		0.450586289167
#   validation loss:		0.633421719074
#   validation accuracy:		65.3194248676 %
# Epoch 218 of 500 took 0.148s
#   training loss:		0.483814299107
#   validation loss:		0.745280504227
#   validation accuracy:		58.2138180733 %
# Epoch 219 of 500 took 0.146s
#   training loss:		0.584811806679
#   validation loss:		1.03037595749
#   validation accuracy:		56.9752275944 %
# Epoch 220 of 500 took 0.148s
#   training loss:		0.853567898273
#   validation loss:		1.02026736736
#   validation accuracy:		50.3911316395 %
# Epoch 221 of 500 took 0.144s
#   training loss:		0.839510798454
#   validation loss:		1.04004180431
#   validation accuracy:		56.7796587944 %
# Epoch 222 of 500 took 0.149s
#   training loss:		0.87612259388
#   validation loss:		0.650794386864
#   validation accuracy:		63.4941339493 %
# Epoch 223 of 500 took 0.144s
#   training loss:		0.507390081882
#   validation loss:		0.597315490246
#   validation accuracy:		66.9491529465 %
# Epoch 224 of 500 took 0.148s
#   training loss:		0.464052677155
#   validation loss:		0.588759601116
#   validation accuracy:		68.7092542648 %
# Epoch 225 of 500 took 0.145s
#   training loss:		0.460396915674
#   validation loss:		0.579701840878
#   validation accuracy:		68.3181226254 %
# Epoch 226 of 500 took 0.148s
#   training loss:		0.454754889011
#   validation loss:		0.578959822655
#   validation accuracy:		69.8174715042 %
# Epoch 227 of 500 took 0.144s
#   training loss:		0.454457551241
#   validation loss:		0.578097760677
#   validation accuracy:		69.6870923042 %
# Epoch 228 of 500 took 0.148s
#   training loss:		0.451252698898
#   validation loss:		0.577051103115
#   validation accuracy:		69.6870923042 %
# Epoch 229 of 500 took 0.144s
#   training loss:		0.447691947222
#   validation loss:		0.575835168362
#   validation accuracy:		69.5567131042 %
# Epoch 230 of 500 took 0.148s
#   training loss:		0.441053807735
#   validation loss:		0.57474642992
#   validation accuracy:		69.4263339043 %
# Epoch 231 of 500 took 0.145s
#   training loss:		0.435454010963
#   validation loss:		0.573982894421
#   validation accuracy:		69.4263339043 %
# Epoch 232 of 500 took 0.148s
#   training loss:		0.430324345827
#   validation loss:		0.573537170887
#   validation accuracy:		69.6219027042 %
# Epoch 233 of 500 took 0.145s
#   training loss:		0.42123311758
#   validation loss:		0.573394179344
#   validation accuracy:		69.8174715042 %
# Epoch 234 of 500 took 0.148s
#   training loss:		0.417160183191
#   validation loss:		0.573203623295
#   validation accuracy:		69.6870923042 %
# Epoch 235 of 500 took 0.145s
#   training loss:		0.413610070944
#   validation loss:		0.573405563831
#   validation accuracy:		69.8174715042 %
# Epoch 236 of 500 took 0.148s
#   training loss:		0.411505997181
#   validation loss:		0.57321614027
#   validation accuracy:		69.4915235043 %
# Epoch 237 of 500 took 0.144s
#   training loss:		0.410449773073
#   validation loss:		0.573565423489
#   validation accuracy:		70.2086031437 %
# Epoch 238 of 500 took 0.148s
#   training loss:		0.404328376055
#   validation loss:		0.573231458664
#   validation accuracy:		70.1434135437 %
# Epoch 239 of 500 took 0.145s
#   training loss:		0.401682466269
#   validation loss:		0.574396550655
#   validation accuracy:		69.8174715042 %
# Epoch 240 of 500 took 0.148s
#   training loss:		0.398903727531
#   validation loss:		0.575447916985
#   validation accuracy:		68.9048230648 %
# Epoch 241 of 500 took 0.145s
#   training loss:		0.40005043149
#   validation loss:		0.586822986603
#   validation accuracy:		69.8174715042 %
# Epoch 242 of 500 took 0.148s
#   training loss:		0.406224399805
#   validation loss:		0.619013011456
#   validation accuracy:		66.166883707 %
# Epoch 243 of 500 took 0.144s
#   training loss:		0.432721883059
#   validation loss:		0.762934148312
#   validation accuracy:		59.1264665127 %
# Epoch 244 of 500 took 0.148s
#   training loss:		0.552742779255
#   validation loss:		1.16449356079
#   validation accuracy:		56.6492855549 %
# Epoch 245 of 500 took 0.144s
#   training loss:		0.94064617157
#   validation loss:		1.15352416039
#   validation accuracy:		49.9348104 %
# Epoch 246 of 500 took 0.148s
#   training loss:		0.916449606419
#   validation loss:		1.13012087345
#   validation accuracy:		56.4537167549 %
# Epoch 247 of 500 took 0.145s
#   training loss:		0.933231770992
#   validation loss:		0.603788435459
#   validation accuracy:		67.4054741859 %
# Epoch 248 of 500 took 0.148s
#   training loss:		0.435772687197
#   validation loss:		0.572167038918
#   validation accuracy:		69.1655814648 %
# Epoch 249 of 500 took 0.145s
#   training loss:		0.42146229744
#   validation loss:		0.574770569801
#   validation accuracy:		69.8174715042 %
# Epoch 250 of 500 took 0.148s
#   training loss:		0.431518763304
#   validation loss:		0.573989093304
#   validation accuracy:		69.5567131042 %
# Epoch 251 of 500 took 0.145s
#   training loss:		0.434119999409
#   validation loss:		0.573624372482
#   validation accuracy:		69.1655814648 %
# Epoch 252 of 500 took 0.149s
#   training loss:		0.433162897825
#   validation loss:		0.572951614857
#   validation accuracy:		69.1003918648 %
# Epoch 253 of 500 took 0.144s
#   training loss:		0.425644606352
#   validation loss:		0.57225549221
#   validation accuracy:		69.4915235043 %
# Epoch 254 of 500 took 0.148s
#   training loss:		0.416213840246
#   validation loss:		0.571603894234
#   validation accuracy:		69.6870923042 %
# Epoch 255 of 500 took 0.144s
#   training loss:		0.407897979021
#   validation loss:		0.57129150629
#   validation accuracy:		69.7522819042 %
# Epoch 256 of 500 took 0.148s
#   training loss:		0.399819731712
#   validation loss:		0.571009039879
#   validation accuracy:		69.9478507042 %
# Epoch 257 of 500 took 0.146s
#   training loss:		0.392786055803
#   validation loss:		0.57126969099
#   validation accuracy:		70.2737927437 %
# Epoch 258 of 500 took 0.148s
#   training loss:		0.388454645872
#   validation loss:		0.571551203728
#   validation accuracy:		70.2086031437 %
# Epoch 259 of 500 took 0.144s
#   training loss:		0.38408446312
#   validation loss:		0.571981906891
#   validation accuracy:		70.0130403042 %
# Epoch 260 of 500 took 0.148s
#   training loss:		0.378354281187
#   validation loss:		0.572824835777
#   validation accuracy:		70.1434135437 %
# Epoch 261 of 500 took 0.144s
#   training loss:		0.374585866928
#   validation loss:		0.573276877403
#   validation accuracy:		69.7522819042 %
# Epoch 262 of 500 took 0.148s
#   training loss:		0.372725456953
#   validation loss:		0.574193954468
#   validation accuracy:		70.1434135437 %
# Epoch 263 of 500 took 0.145s
#   training loss:		0.368592917919
#   validation loss:		0.574190437794
#   validation accuracy:		69.9478507042 %
# Epoch 264 of 500 took 0.147s
#   training loss:		0.367777168751
#   validation loss:		0.576335847378
#   validation accuracy:		70.0782239437 %
# Epoch 265 of 500 took 0.146s
#   training loss:		0.361557662487
#   validation loss:		0.576670348644
#   validation accuracy:		70.0782239437 %
# Epoch 266 of 500 took 0.148s
#   training loss:		0.360133081675
#   validation loss:		0.586697161198
#   validation accuracy:		70.2086031437 %
# Epoch 267 of 500 took 0.145s
#   training loss:		0.366771101952
#   validation loss:		0.613259255886
#   validation accuracy:		68.1225538254 %
# Epoch 268 of 500 took 0.148s
#   training loss:		0.387823343277
#   validation loss:		0.758026003838
#   validation accuracy:		61.147326231 %
# Epoch 269 of 500 took 0.144s
#   training loss:		0.501810729504
#   validation loss:		1.23860061169
#   validation accuracy:		57.3663651943 %
# Epoch 270 of 500 took 0.148s
#   training loss:		0.968408346176
#   validation loss:		1.31942105293
#   validation accuracy:		49.6740549803 %
# Epoch 271 of 500 took 0.144s
#   training loss:		1.01387465
#   validation loss:		1.21628332138
#   validation accuracy:		55.7366371155 %
# Epoch 272 of 500 took 0.147s
#   training loss:		0.983940899372
#   validation loss:		0.568873763084
#   validation accuracy:		70.7301199436 %
# Epoch 273 of 500 took 0.146s
#   training loss:		0.3873282969
#   validation loss:		0.573901772499
#   validation accuracy:		70.0130403042 %
# Epoch 274 of 500 took 0.148s
#   training loss:		0.408183932304
#   validation loss:		0.569263756275
#   validation accuracy:		69.8174715042 %
# Epoch 275 of 500 took 0.144s
#   training loss:		0.415738105774
#   validation loss:		0.571234643459
#   validation accuracy:		69.7522819042 %
# Epoch 276 of 500 took 0.148s
#   training loss:		0.417980492115
#   validation loss:		0.571802318096
#   validation accuracy:		69.2959606647 %
# Epoch 277 of 500 took 0.144s
#   training loss:		0.413914889097
#   validation loss:		0.571686446667
#   validation accuracy:		69.2307710648 %
# Epoch 278 of 500 took 0.148s
#   training loss:		0.403938353062
#   validation loss:		0.571827530861
#   validation accuracy:		69.6219027042 %
# Epoch 279 of 500 took 0.145s
#   training loss:		0.392888724804
#   validation loss:		0.571981310844
#   validation accuracy:		69.6870923042 %
# Epoch 280 of 500 took 0.148s
#   training loss:		0.381769299507
#   validation loss:		0.572665393353
#   validation accuracy:		70.4693615437 %
# Epoch 281 of 500 took 0.145s
#   training loss:		0.370415449142
#   validation loss:		0.572976648808
#   validation accuracy:		70.0130403042 %
# Epoch 282 of 500 took 0.148s
#   training loss:		0.359685778618
#   validation loss:		0.57387471199
#   validation accuracy:		70.0130403042 %
# Epoch 283 of 500 took 0.145s
#   training loss:		0.353997528553
#   validation loss:		0.574454069138
#   validation accuracy:		70.0130403042 %
# Epoch 284 of 500 took 0.149s
#   training loss:		0.348208606243
#   validation loss:		0.576222538948
#   validation accuracy:		69.9478507042 %
# Epoch 285 of 500 took 0.144s
#   training loss:		0.342964619398
#   validation loss:		0.577115595341
#   validation accuracy:		70.1434135437 %
# Epoch 286 of 500 took 0.148s
#   training loss:		0.341975063086
#   validation loss:		0.579086601734
#   validation accuracy:		70.2086031437 %
# Epoch 287 of 500 took 0.144s
#   training loss:		0.3351816535
#   validation loss:		0.579791665077
#   validation accuracy:		69.8174715042 %
# Epoch 288 of 500 took 0.147s
#   training loss:		0.339863955975
#   validation loss:		0.585310339928
#   validation accuracy:		70.0130403042 %
# Epoch 289 of 500 took 0.145s
#   training loss:		0.333570092916
#   validation loss:		0.588483393192
#   validation accuracy:		70.2737927437 %
# Epoch 290 of 500 took 0.148s
#   training loss:		0.336280524731
#   validation loss:		0.62603276968
#   validation accuracy:		68.5136914253 %
# Epoch 291 of 500 took 0.146s
#   training loss:		0.356706053019
#   validation loss:		0.737749278545
#   validation accuracy:		64.8631036282 %
# Epoch 292 of 500 took 0.148s
#   training loss:		0.464127451181
#   validation loss:		1.10902225971
#   validation accuracy:		52.6727497578 %
# Epoch 293 of 500 took 0.148s
#   training loss:		0.771508276463
#   validation loss:		1.67107975483
#   validation accuracy:		54.1069090366 %
# Epoch 294 of 500 took 0.150s
#   training loss:		1.35585713387
#   validation loss:		0.663242042065
#   validation accuracy:		65.6453728676 %
# Epoch 295 of 500 took 0.148s
#   training loss:		0.408772975206
#   validation loss:		0.580987989902
#   validation accuracy:		68.6440706253 %
# Epoch 296 of 500 took 0.149s
#   training loss:		0.361733853817
#   validation loss:		0.580467283726
#   validation accuracy:		68.5788810253 %
# Epoch 297 of 500 took 0.145s
#   training loss:		0.367801427841
#   validation loss:		0.563743233681
#   validation accuracy:		69.3611502647 %
# Epoch 298 of 500 took 0.148s
#   training loss:		0.362874090672
#   validation loss:		0.564160227776
#   validation accuracy:		70.4041719437 %
# Epoch 299 of 500 took 0.145s
#   training loss:		0.365987181664
#   validation loss:		0.563897430897
#   validation accuracy:		69.7522819042 %
# Epoch 300 of 500 took 0.147s
#   training loss:		0.361593782902
#   validation loss:		0.564833700657
#   validation accuracy:		69.7522819042 %
# Epoch 301 of 500 took 0.145s
#   training loss:		0.356534093618
#   validation loss:		0.566294908524
#   validation accuracy:		70.0130403042 %
# Epoch 302 of 500 took 0.148s
#   training loss:		0.346765995026
#   validation loss:		0.568124711514
#   validation accuracy:		70.0130403042 %
# Epoch 303 of 500 took 0.145s
#   training loss:		0.337766736746
#   validation loss:		0.569183170795
#   validation accuracy:		69.8174715042 %
# Epoch 304 of 500 took 0.148s
#   training loss:		0.327195256948
#   validation loss:		0.57207852602
#   validation accuracy:		70.7953035831 %
# Epoch 305 of 500 took 0.145s
#   training loss:		0.3201572299
#   validation loss:		0.5729637146
#   validation accuracy:		69.8174715042 %
# Epoch 306 of 500 took 0.148s
#   training loss:		0.313779294491
#   validation loss:		0.576024651527
#   validation accuracy:		69.9478507042 %
# Epoch 307 of 500 took 0.145s
#   training loss:		0.308376193047
#   validation loss:		0.576897978783
#   validation accuracy:		70.2737927437 %
# Epoch 308 of 500 took 0.148s
#   training loss:		0.307879775763
#   validation loss:		0.580535411835
#   validation accuracy:		69.8826611042 %
# Epoch 309 of 500 took 0.145s
#   training loss:		0.302938699722
#   validation loss:		0.581137478352
#   validation accuracy:		70.2737927437 %
# Epoch 310 of 500 took 0.148s
#   training loss:		0.298329412937
#   validation loss:		0.587208509445
#   validation accuracy:		69.8174715042 %
# Epoch 311 of 500 took 0.144s
#   training loss:		0.298249959946
#   validation loss:		0.588239431381
#   validation accuracy:		69.8826611042 %
# Epoch 312 of 500 took 0.148s
#   training loss:		0.301147907972
#   validation loss:		0.611842811108
#   validation accuracy:		68.9700126648 %
# Epoch 313 of 500 took 0.145s
#   training loss:		0.308487325907
#   validation loss:		0.653065919876
#   validation accuracy:		68.9048230648 %
# Epoch 314 of 500 took 0.147s
#   training loss:		0.351232677698
#   validation loss:		0.859104573727
#   validation accuracy:		60.5606257915 %
# Epoch 315 of 500 took 0.145s
#   training loss:		0.504931390285
#   validation loss:		1.3767977953
#   validation accuracy:		57.8878760338 %
# Epoch 316 of 500 took 0.148s
#   training loss:		1.01251924038
#   validation loss:		1.08940923214
#   validation accuracy:		53.5202085972 %
# Epoch 317 of 500 took 0.147s
#   training loss:		0.703873991966
#   validation loss:		1.0472151041
#   validation accuracy:		59.2568457127 %
# Epoch 318 of 500 took 0.149s
#   training loss:		0.742263972759
#   validation loss:		0.601657509804
#   validation accuracy:		67.5358533859 %
# Epoch 319 of 500 took 0.145s
#   training loss:		0.342632442713
#   validation loss:		0.561085104942
#   validation accuracy:		70.0782239437 %
# Epoch 320 of 500 took 0.147s
#   training loss:		0.326757103205
#   validation loss:		0.564906775951
#   validation accuracy:		70.7301199436 %
# Epoch 321 of 500 took 0.145s
#   training loss:		0.332951039076
#   validation loss:		0.565297484398
#   validation accuracy:		70.2086031437 %
# Epoch 322 of 500 took 0.147s
#   training loss:		0.334069103003
#   validation loss:		0.567430794239
#   validation accuracy:		70.1434135437 %
# Epoch 323 of 500 took 0.146s
#   training loss:		0.327788382769
#   validation loss:		0.569633901119
#   validation accuracy:		70.0130403042 %
# Epoch 324 of 500 took 0.148s
#   training loss:		0.31809052825
#   validation loss:		0.571739256382
#   validation accuracy:		70.2737927437 %
# Epoch 325 of 500 took 0.144s
#   training loss:		0.306568711996
#   validation loss:		0.573248445988
#   validation accuracy:		70.5345511436 %
# Epoch 326 of 500 took 0.148s
#   training loss:		0.298326909542
#   validation loss:		0.576616764069
#   validation accuracy:		70.5345511436 %
# Epoch 327 of 500 took 0.144s
#   training loss:		0.289295315742
#   validation loss:		0.578808069229
#   validation accuracy:		70.2086031437 %
# Epoch 328 of 500 took 0.148s
#   training loss:		0.283188164234
#   validation loss:		0.58254134655
#   validation accuracy:		70.3389823437 %
# Epoch 329 of 500 took 0.145s
#   training loss:		0.278698891401
#   validation loss:		0.585406780243
#   validation accuracy:		70.2737927437 %
# Epoch 330 of 500 took 0.147s
#   training loss:		0.273647576571
#   validation loss:		0.588370203972
#   validation accuracy:		70.0130403042 %
# Epoch 331 of 500 took 0.145s
#   training loss:		0.269973039627
#   validation loss:		0.590899348259
#   validation accuracy:		69.8174715042 %
# Epoch 332 of 500 took 0.148s
#   training loss:		0.268448024988
#   validation loss:		0.592794179916
#   validation accuracy:		70.1434135437 %
# Epoch 333 of 500 took 0.145s
#   training loss:		0.264067977667
#   validation loss:		0.595157980919
#   validation accuracy:		70.3389823437 %
# Epoch 334 of 500 took 0.148s
#   training loss:		0.256071090698
#   validation loss:		0.596250116825
#   validation accuracy:		70.3389823437 %
# Epoch 335 of 500 took 0.145s
#   training loss:		0.258038669825
#   validation loss:		0.598616719246
#   validation accuracy:		70.0130403042 %
# Epoch 336 of 500 took 0.148s
#   training loss:		0.255147337914
#   validation loss:		0.597736001015
#   validation accuracy:		70.4041719437 %
# Epoch 337 of 500 took 0.145s
#   training loss:		0.254039764404
#   validation loss:		0.605842828751
#   validation accuracy:		69.4915235043 %
# Epoch 338 of 500 took 0.147s
#   training loss:		0.256394833326
#   validation loss:		0.616034209728
#   validation accuracy:		70.2737927437 %
# Epoch 339 of 500 took 0.145s
#   training loss:		0.263399630785
#   validation loss:		0.71095252037
#   validation accuracy:		67.275094986 %
# Epoch 340 of 500 took 0.148s
#   training loss:		0.324983477592
#   validation loss:		1.01449644566
#   validation accuracy:		61.473274231 %
# Epoch 341 of 500 took 0.145s
#   training loss:		0.602663457394
#   validation loss:		1.5247926712
#   validation accuracy:		50.7822692394 %
# Epoch 342 of 500 took 0.148s
#   training loss:		1.01407432556
#   validation loss:		1.73231577873
#   validation accuracy:		54.1720986366 %
# Epoch 343 of 500 took 0.144s
#   training loss:		1.36787414551
#   validation loss:		0.55840241909
#   validation accuracy:		69.4915235043 %
# Epoch 344 of 500 took 0.148s
#   training loss:		0.316555470228
#   validation loss:		0.604017496109
#   validation accuracy:		66.6232049465 %
# Epoch 345 of 500 took 0.145s
#   training loss:		0.383569091558
#   validation loss:		0.56304204464
#   validation accuracy:		69.2959606647 %
# Epoch 346 of 500 took 0.147s
#   training loss:		0.362524718046
#   validation loss:		0.566950142384
#   validation accuracy:		69.1003918648 %
# Epoch 347 of 500 took 0.145s
#   training loss:		0.362637549639
#   validation loss:		0.571146428585
#   validation accuracy:		69.0352022648 %
# Epoch 348 of 500 took 0.148s
#   training loss:		0.350295424461
#   validation loss:		0.575522422791
#   validation accuracy:		69.5567131042 %
# Epoch 349 of 500 took 0.144s
#   training loss:		0.334228515625
#   validation loss:		0.578105807304
#   validation accuracy:		69.8826611042 %
# Epoch 350 of 500 took 0.148s
#   training loss:		0.318617403507
#   validation loss:		0.58002114296
#   validation accuracy:		70.3389823437 %
# Epoch 351 of 500 took 0.145s
# ...
#   validation accuracy:		72.0156550407 %
# Epoch 410 of 500 took 0.145s
#   training loss:		0.198749452829
#   validation loss:		0.601526021957
#   validation accuracy:		72.2765803337 %
# Epoch 411 of 500 took 0.144s
#   training loss:		0.190695494413
#   validation loss:		0.609704494476
#   validation accuracy:		72.2113490105 %
# Epoch 412 of 500 took 0.145s
#   training loss:		0.188711091876
#   validation loss:		0.621393084526
#   validation accuracy:		72.4722743034 %
# Epoch 413 of 500 took 0.145s
#   training loss:		0.17889380455
#   validation loss:		0.627082467079
#   validation accuracy:		72.6679742336 %
# Epoch 414 of 500 took 0.145s
#   training loss:		0.17998483777
#   validation loss:		0.645165383816
#   validation accuracy:		71.2981104851 %
# Epoch 415 of 500 took 0.144s
#   training loss:		0.175549030304
#   validation loss:		0.651901602745
#   validation accuracy:		72.8636682034 %
# Epoch 416 of 500 took 0.145s
#   training loss:		0.17935743928
#   validation loss:		0.731427848339
#   validation accuracy:		69.3411588669 %
# Epoch 417 of 500 took 0.144s
#   training loss:		0.212075263262
#   validation loss:		0.914942860603
#   validation accuracy:		68.6888456345 %
# Epoch 418 of 500 took 0.145s
#   training loss:		0.394253611565
#   validation loss:		1.80547809601
#   validation accuracy:		53.0332684517 %
# Epoch 419 of 500 took 0.144s
#   training loss:		1.11428070068
#   validation loss:		2.79515528679
#   validation accuracy:		52.5114178658 %
# Epoch 420 of 500 took 0.146s
#   training loss:		2.42567157745
#   validation loss:		0.976122260094
#   validation accuracy:		59.5564246178 %
# Epoch 421 of 500 took 0.144s
#   training loss:		0.672688901424
#   validation loss:		0.640976905823
#   validation accuracy:		64.7097170353 %
# Epoch 422 of 500 took 0.146s
#   training loss:		0.374062538147
#   validation loss:		0.591097950935
#   validation accuracy:		67.0580565929 %
# Epoch 423 of 500 took 0.144s
#   training loss:		0.361564189196
#   validation loss:		0.55756342411
#   validation accuracy:		70.5805599689 %
# Epoch 424 of 500 took 0.146s
#   training loss:		0.351967185736
#   validation loss:		0.559750258923
#   validation accuracy:		69.4716215134 %
# Epoch 425 of 500 took 0.144s
#   training loss:		0.36051440239
#   validation loss:		0.561867594719
#   validation accuracy:		68.9497709274 %
# Epoch 426 of 500 took 0.146s
#   training loss:		0.35958686471
#   validation loss:		0.562069237232
#   validation accuracy:		68.8845396042 %
# Epoch 427 of 500 took 0.144s
#   training loss:		0.353204488754
#   validation loss:		0.560439050198
#   validation accuracy:		69.1454648972 %
# Epoch 428 of 500 took 0.146s
#   training loss:		0.339117288589
#   validation loss:		0.557775318623
#   validation accuracy:		69.4063901901 %
# Epoch 429 of 500 took 0.144s
#   training loss:		0.331893205643
#   validation loss:		0.554361999035
#   validation accuracy:		70.1891720295 %
# Epoch 430 of 500 took 0.146s
#   training loss:		0.317023575306
#   validation loss:		0.554030060768
#   validation accuracy:		70.7762539387 %
# Epoch 431 of 500 took 0.144s
#   training loss:		0.302311182022
#   validation loss:		0.554407179356
#   validation accuracy:		71.2981104851 %
# Epoch 432 of 500 took 0.146s
#   training loss:		0.293372064829
#   validation loss:		0.556278169155
#   validation accuracy:		71.9504237175 %
# Epoch 433 of 500 took 0.143s
#   training loss:		0.277656823397
#   validation loss:		0.561297655106
#   validation accuracy:		71.6894984245 %
# Epoch 434 of 500 took 0.146s
#   training loss:		0.270393311977
#   validation loss:		0.564200401306
#   validation accuracy:		72.7984368801 %
# Epoch 435 of 500 took 0.144s
#   training loss:		0.259039819241
#   validation loss:		0.575293958187
#   validation accuracy:		70.9067165852 %
# Epoch 436 of 500 took 0.146s
#   training loss:		0.252656251192
#   validation loss:		0.578858792782
#   validation accuracy:		72.9941308498 %
# Epoch 437 of 500 took 0.144s
#   training loss:		0.253345638514
#   validation loss:		0.623472094536
#   validation accuracy:		69.2759275436 %
# Epoch 438 of 500 took 0.146s
#   training loss:		0.258571624756
#   validation loss:		0.70461833477
#   validation accuracy:		69.0802335739 %
# Epoch 439 of 500 took 0.143s
#   training loss:		0.3450101614
#   validation loss:		1.09998512268
#   validation accuracy:		56.8819284439 %
# Epoch 440 of 500 took 0.146s
#   training loss:		0.657458424568
#   validation loss:		1.67971086502
#   validation accuracy:		55.3163707256 %
# Epoch 441 of 500 took 0.144s
#   training loss:		1.33831453323
#   validation loss:		0.57231092453
#   validation accuracy:		70.5153286457 %
# Epoch 442 of 500 took 0.146s
#   training loss:		0.264951020479
#   validation loss:		0.553761124611
#   validation accuracy:		71.0371792316 %
# Epoch 443 of 500 took 0.143s
#   training loss:		0.270987272263
#   validation loss:		0.548520863056
#   validation accuracy:		71.1024165154 %
# Epoch 444 of 500 took 0.146s
#   training loss:		0.277751594782
#   validation loss:		0.549972772598
#   validation accuracy:		71.2981104851 %
# Epoch 445 of 500 took 0.143s
#   training loss:		0.276443719864
#   validation loss:		0.552299380302
#   validation accuracy:		71.559035778 %
# Epoch 446 of 500 took 0.148s
#   training loss:		0.270588070154
#   validation loss:		0.55474460125
#   validation accuracy:		71.7547297478 %
# Epoch 447 of 500 took 0.144s
#   training loss:		0.266855567694
#   validation loss:		0.559117853642
#   validation accuracy:		71.559035778 %
# Epoch 448 of 500 took 0.146s
#   training loss:		0.255492806435
#   validation loss:		0.563345491886
#   validation accuracy:		71.8851923943 %
# Epoch 449 of 500 took 0.144s
#   training loss:		0.250869095325
#   validation loss:		0.567297875881
#   validation accuracy:		71.559035778 %
# Epoch 450 of 500 took 0.146s
#   training loss:		0.243920728564
#   validation loss:		0.573113501072
#   validation accuracy:		71.3633418083 %
# Epoch 451 of 500 took 0.144s
#   training loss:		0.235344335437
#   validation loss:		0.577026069164
#   validation accuracy:		71.4938044548 %
# Epoch 452 of 500 took 0.145s
#   training loss:		0.228967890143
#   validation loss:		0.58365213871
#   validation accuracy:		71.2328791618 %
# Epoch 453 of 500 took 0.144s
#   training loss:		0.228655353189
#   validation loss:		0.586041748524
#   validation accuracy:		72.1461176872 %
# Epoch 454 of 500 took 0.146s
#   training loss:		0.224730446935
#   validation loss:		0.589410126209
#   validation accuracy:		72.5375056267 %
# Epoch 455 of 500 took 0.145s
#   training loss:		0.218069240451
#   validation loss:		0.596678972244
#   validation accuracy:		71.819961071 %
# Epoch 456 of 500 took 0.146s
#   training loss:		0.214382708073
#   validation loss:		0.598709523678
#   validation accuracy:		72.7984368801 %
# Epoch 457 of 500 took 0.144s
#   training loss:		0.211993277073
#   validation loss:		0.629686355591
#   validation accuracy:		70.1239407063 %
# Epoch 458 of 500 took 0.146s
#   training loss:		0.223866418004
#   validation loss:		0.677107155323
#   validation accuracy:		70.3848659992 %
# Epoch 459 of 500 took 0.144s
#   training loss:		0.276419579983
#   validation loss:		0.983074963093
#   validation accuracy:		59.621655941 %
# Epoch 460 of 500 took 0.146s
#   training loss:		0.484683007002
#   validation loss:		1.60012984276
#   validation accuracy:		56.4253091812 %
# Epoch 461 of 500 took 0.144s
#   training loss:		1.21117281914
#   validation loss:		0.757152795792
#   validation accuracy:		63.9921724796 %
# Epoch 462 of 500 took 0.146s
#   training loss:		0.346641987562
#   validation loss:		0.619930505753
#   validation accuracy:		71.2981104851 %
# Epoch 463 of 500 took 0.144s
#   training loss:		0.280445873737
#   validation loss:		0.586750924587
#   validation accuracy:		69.4716215134 %
# Epoch 464 of 500 took 0.146s
#   training loss:		0.243289917707
#   validation loss:		0.566264569759
#   validation accuracy:		72.2765803337 %
# Epoch 465 of 500 took 0.144s
#   training loss:		0.231936335564
#   validation loss:		0.569026052952
#   validation accuracy:		71.7547297478 %
# Epoch 466 of 500 took 0.146s
#   training loss:		0.224933356047
#   validation loss:		0.571065783501
#   validation accuracy:		72.0156550407 %
# Epoch 467 of 500 took 0.144s
#   training loss:		0.216787055135
#   validation loss:		0.577140331268
#   validation accuracy:		72.2113490105 %
# Epoch 468 of 500 took 0.146s
#   training loss:		0.214326128364
#   validation loss:		0.582205891609
#   validation accuracy:		72.4722743034 %
# Epoch 469 of 500 took 0.144s
#   training loss:		0.205602094531
#   validation loss:		0.587415158749
#   validation accuracy:		71.8851923943 %
# Epoch 470 of 500 took 0.146s
#   training loss:		0.203668370843
#   validation loss:		0.593715667725
#   validation accuracy:		72.2765803337 %
# Epoch 471 of 500 took 0.144s
#   training loss:		0.192790970206
#   validation loss:		0.597607254982
#   validation accuracy:		72.5375056267 %
# Epoch 472 of 500 took 0.146s
#   training loss:		0.189343482256
#   validation loss:		0.604196548462
#   validation accuracy:		72.6679742336 %
# Epoch 473 of 500 took 0.144s
#   training loss:		0.185594141483
#   validation loss:		0.608626663685
#   validation accuracy:		72.7332055569 %
# Epoch 474 of 500 took 0.146s
#   training loss:		0.181435644627
#   validation loss:		0.619235575199
#   validation accuracy:		72.080886364 %
# Epoch 475 of 500 took 0.144s
#   training loss:		0.180178046227
#   validation loss:		0.620559513569
#   validation accuracy:		72.6679742336 %
# Epoch 476 of 500 took 0.145s
#   training loss:		0.178088501096
#   validation loss:		0.65035867691
#   validation accuracy:		70.6457912922 %
# Epoch 477 of 500 took 0.144s
#   training loss:		0.181452780962
#   validation loss:		0.668730556965
#   validation accuracy:		71.4938044548 %
# Epoch 478 of 500 took 0.146s
#   training loss:		0.205819547176
#   validation loss:		0.834600448608
#   validation accuracy:		65.5577301979 %
# Epoch 479 of 500 took 0.144s
#   training loss:		0.295283913612
#   validation loss:		1.20958352089
#   validation accuracy:		62.4266147614 %
# Epoch 480 of 500 took 0.145s
#   training loss:		0.694357216358
#   validation loss:		1.72435891628
#   validation accuracy:		53.5551190376 %
# Epoch 481 of 500 took 0.145s
#   training loss:		1.06273543835
#   validation loss:		1.66730129719
#   validation accuracy:		55.0554454327 %
# Epoch 482 of 500 took 0.145s
#   training loss:		1.2840462923
#   validation loss:		0.684929251671
#   validation accuracy:		67.7103698254 %
# Epoch 483 of 500 took 0.144s
#   training loss:		0.369543015957
#   validation loss:		0.67240601778
#   validation accuracy:		64.8401796818 %
# Epoch 484 of 500 took 0.145s
#   training loss:		0.363939970732
#   validation loss:		0.557901442051
#   validation accuracy:		70.5805599689 %
# Epoch 485 of 500 took 0.144s
#   training loss:		0.280686229467
#   validation loss:		0.557610929012
#   validation accuracy:		70.3848659992 %
# Epoch 486 of 500 took 0.146s
#   training loss:		0.273595631123
#   validation loss:		0.562080323696
#   validation accuracy:		70.319634676 %
# Epoch 487 of 500 took 0.144s
#   training loss:		0.263367801905
#   validation loss:		0.569123983383
#   validation accuracy:		71.0371792316 %
# Epoch 488 of 500 took 0.146s
#   training loss:		0.25303453207
#   validation loss:		0.577408015728
#   validation accuracy:		71.4285731316 %
# Epoch 489 of 500 took 0.144s
#   training loss:		0.235490977764
#   validation loss:		0.584748625755
#   validation accuracy:		71.6242671013 %
# Epoch 490 of 500 took 0.146s
#   training loss:		0.230488240719
#   validation loss:		0.587851822376
#   validation accuracy:		71.4938044548 %
# Epoch 491 of 500 took 0.144s
#   training loss:		0.21713128686
#   validation loss:		0.603666186333
#   validation accuracy:		71.0371792316 %
# Epoch 492 of 500 took 0.146s
#   training loss:		0.216861665249
#   validation loss:		0.601494669914
#   validation accuracy:		71.4938044548 %
# Epoch 493 of 500 took 0.144s
#   training loss:		0.224596202374
#   validation loss:		0.745558083057
#   validation accuracy:		67.0580565929 %
# Epoch 494 of 500 took 0.147s
#   training loss:		0.287997424603
#   validation loss:		1.31947612762
#   validation accuracy:		58.4474861622 %
# Epoch 495 of 500 took 0.144s
#   training loss:		0.938480615616
#   validation loss:		2.41574335098
#   validation accuracy:		47.4885851145 %
# Epoch 496 of 500 took 0.146s
#   training loss:		1.88861072063
#   validation loss:		1.12992298603
#   validation accuracy:		55.7729959488 %
# Epoch 497 of 500 took 0.143s
#   training loss:		0.880568265915
#   validation loss:		0.628723204136
#   validation accuracy:		67.1885192394 %
# Epoch 498 of 500 took 0.147s
#   training loss:		0.46418762207
#   validation loss:		0.611268520355
#   validation accuracy:		65.2968049049 %
# Epoch 499 of 500 took 0.144s
#   training loss:		0.47792711854
#   validation loss:		0.607967674732
#   validation accuracy:		66.0143494606 %
# Epoch 500 of 500 took 0.146s
#   training loss:		0.47773167491
#   validation loss:		0.577208459377
#   validation accuracy:		69.6673214436 %
# ('TRAIN:', array([   0,    1,    2, ..., 3791, 3792, 3793]), 'TEST:', array([1456, 1457, 1458, ..., 4596, 4597, 4598]))
# train freq [1456 1611]
# val freq [727 805]
# Loading data...
# Building model and compiling functions...
# Starting training...
# ---------------------------------------------------------------------------
# GpuArrayException                         Traceback (most recent call last)
# <ipython-input-6-43ba018e1687> in <module>()
#      11     print "val freq", freq_val[:,1]
#      12
# ---> 13     train_cnn(data_train, label_train, data_val, label_val, data_val)
#
# <ipython-input-5-e6055806fa8e> in train_cnn(X_train, y_train, X_val, y_val, X_test, num_epochs)
#      53         start_time = time.time()
#      54         # In each epoch, we do a full pass over the training data:
# ---> 55         train_err = train_fn(X_train, y_train)
#      56         # And a full pass over the validation data:
#      57         val_err, val_acc = val_fn(X_val, y_val)
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     896                     node=self.fn.nodes[self.fn.position_of_error],
#     897                     thunk=thunk,
# --> 898                     storage_map=getattr(self.fn, 'storage_map', None))
#     899             else:
#     900                 # old-style linkers raise their own exceptions
#
# /usr/local/lib/python2.7/dist-packages/theano/gof/link.pyc in raise_with_op(node, thunk, exc_info, storage_map)
#     323         # extra long error message in that case.
#     324         pass
# --> 325     reraise(exc_type, exc_value, exc_trace)
#     326
#     327
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     882         try:
#     883             outputs =\
# --> 884                 self.fn() if output_subset is None else\
#     885                 self.fn(output_subset=output_subset)
#     886         except Exception:
#
# pygpu/gpuarray.pyx in pygpu.gpuarray.pygpu_empty (pygpu/gpuarray.c:9764)()
#
# pygpu/gpuarray.pyx in pygpu.gpuarray.array_empty (pygpu/gpuarray.c:5616)()
#
# GpuArrayException: out of memory
# Apply node that caused the error: GpuDnnPoolGrad{mode='max'}(GpuContiguous.0, GpuContiguous.0, GpuContiguous.0, TensorConstant{(2,) of 2}, TensorConstant{(2,) of 2}, TensorConstant{(2,) of 0})
# Toposort index: 233
# Inputs types: [GpuArrayType<None>(float32, (False, False, False, False)), GpuArrayType<None>(float32, (False, False, False, False)), GpuArrayType<None>(float32, (False, False, False, False)), TensorType(int64, vector), TensorType(int64, vector), TensorType(int64, vector)]
# Inputs shapes: [(3067, 32, 20, 100), (3067, 32, 10, 50), (3067, 32, 10, 50), (2,), (2,), (2,)]
# Inputs strides: [(256000, 8000, 400, 4), (64000, 2000, 200, 4), (64000, 2000, 200, 4), (8,), (8,), (8,)]
# Inputs values: ['not shown', 'not shown', 'not shown', array([2, 2]), array([2, 2]), array([0, 0])]
# Outputs clients: [[GpuElemwise{Composite{((i0 * i1) + (i2 * i1 * sgn(i3)))}}[(0, 1)]<gpuarray>(GpuArrayConstant{[[[[ 0.5]]]]}, GpuDnnPoolGrad{mode='max'}.0, GpuArrayConstant{[[[[ 0.5]]]]}, GpuElemwise{Add}[(0, 0)]<gpuarray>.0)]]
#
# HINT: Re-running with most Theano optimization disabled could give you a back-trace of when this node was created. This can be done with by setting the Theano flag 'optimizer=fast_compile'. If that does not work, Theano optimizations can be disabled with 'optimizer=None'.
# HINT: Use the Theano flag 'exception_verbosity=high' for a debugprint and storage map footprint of this apply node.
